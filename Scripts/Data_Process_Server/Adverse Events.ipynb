# %%
import numpy as np
import pandas as pd
from Abstract import Abstract
import re
import requests
read_prefix = '/data/MIMIC3/%s.csv'
write_prefix = '/data/liu/mimic3/%s.csv'
aa = Abstract(read_prefix=read_prefix,write_prefix=write_prefix)

# %% [markdown]
# ## Diagnoses (ICD9_CODE)

# %%
diag_df = aa.read_data('DIAGNOSES_ICD')

# %%
diag_df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0    1297         109   172335      1.0     40301
# 1    1298         109   172335      2.0       486
# 2    1299         109   172335      3.0     58281
# 3    1300         109   172335      4.0      5855
# 4    1301         109   172335      5.0      4254

# %%
diag_df[diag_df['ICD9_CODE']=='2355']
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 14051    14316        1249   103686      1.0      2355
# 164851  163444       14615   163684      7.0      2355
# 210343  210996       18969   167233      1.0      2355
# 386467  386075       41520   158306      9.0      2355
# 437718  440171       53342   171013     19.0      2355
# 599445  624769       94307   108480      9.0      2355
# 648508  650209       99817   195557     17.0      2355

# %%
diag_code_df = aa.read_data('D_ICD_DIAGNOSES')
diag_code_df.head()
# Out:
#    ROW_ID ICD9_CODE               SHORT_TITLE                                         LONG_TITLE
# 0     174     01166     TB pneumonia-oth test  Tuberculous pneumonia [any form], tubercle bac...
# 1     175     01170    TB pneumothorax-unspec              Tuberculous pneumothorax, unspecified
# 2     176     01171   TB pneumothorax-no exam  Tuberculous pneumothorax, bacteriological or h...
# 3     177     01172  TB pneumothorx-exam unkn  Tuberculous pneumothorax, bacteriological or h...
# 4     178     01173  TB pneumothorax-micro dx  Tuberculous pneumothorax, tubercle bacilli fou...

# %%
diag_code_df[diag_code_df['ICD9_CODE']=='2355']
# Out:
#       ROW_ID ICD9_CODE           SHORT_TITLE                                         LONG_TITLE
# 1714    1717      2355  Unc behav neo GI NEC  Neoplasm of uncertain behavior of other and un...

# %% [markdown]
# ## Prescriptions

# %%
usecols=["SUBJECT_ID", "STARTDATE", "ENDDATE","DRUG","NDC","DRUG_NAME_GENERIC","ROUTE"]
pres_df = pd.read_csv(read_prefix%'PRESCRIPTIONS',usecols=usecols,dtype={'NDC': str})
pres_df.head()

# %%
pres_df[pres_df['DRUG']!=pres_df['DRUG_NAME_GENERIC']]
# Out:
#          SUBJECT_ID            STARTDATE              ENDDATE  \
# 2                 6  2175-06-11 00:00:00  2175-06-12 00:00:00
# 3                 6  2175-06-11 00:00:00  2175-06-12 00:00:00
# 6                 6  2175-06-12 00:00:00  2175-06-12 00:00:00
# 7                 6  2175-06-12 00:00:00  2175-06-12 00:00:00
# 8                 6  2175-06-12 00:00:00  2175-06-13 00:00:00
# 10                6  2175-06-12 00:00:00  2175-06-13 00:00:00
# 16                6  2175-06-13 00:00:00  2175-06-14 00:00:00
# 17                6  2175-06-13 00:00:00  2175-06-14 00:00:00
# 23               13  2167-01-08 00:00:00  2167-01-09 00:00:00
# 24               13  2167-01-08 00:00:00  2167-01-09 00:00:00
# 25               13  2167-01-08 00:00:00  2167-01-09 00:00:00
# 38               13  2167-01-09 00:00:00  2167-01-11 00:00:00
# 39               13  2167-01-09 00:00:00  2167-01-11 00:00:00
# 40               13  2167-01-09 00:00:00  2167-01-12 00:00:00
# 43               13  2167-01-09 00:00:00  2167-01-12 00:00:00
# 48               13  2167-01-09 00:00:00  2167-01-12 00:00:00
# 49               13  2167-01-09 00:00:00  2167-01-12 00:00:00
# 50               13  2167-01-09 00:00:00  2167-01-12 00:00:00
# 51               13  2167-01-09 00:00:00  2167-01-12 00:00:00
# 52               13  2167-01-09 00:00:00  2167-01-12 00:00:00
# 53               13  2167-01-09 00:00:00  2167-01-12 00:00:00
# 54               13  2167-01-09 00:00:00  2167-01-12 00:00:00
# 56                6  2175-06-14 00:00:00  2175-06-15 00:00:00
# 60                6  2175-06-14 00:00:00  2175-06-15 00:00:00
# 63                6  2175-06-14 00:00:00  2175-06-15 00:00:00
# 69                6  2175-06-15 00:00:00  2175-06-15 00:00:00
# 70                6  2175-06-15 00:00:00  2175-06-15 00:00:00
# 71                8  2117-11-20 00:00:00  2117-11-24 00:00:00
# 72                8  2117-11-20 00:00:00  2117-11-24 00:00:00
# 73                8  2117-11-20 00:00:00  2117-11-24 00:00:00
# ...             ...                  ...                  ...
# 4156389       99995  2147-02-08 00:00:00  2147-02-08 00:00:00
# 4156390       99995  2147-02-08 00:00:00  2147-02-08 00:00:00
# 4156391       99995  2147-02-08 00:00:00  2147-02-08 00:00:00
# 4156392       99995  2147-02-08 00:00:00  2147-02-08 00:00:00
# 4156393       99995  2147-02-08 00:00:00  2147-02-08 00:00:00
# 4156394       99995  2147-02-08 00:00:00  2147-02-08 00:00:00
# 4156395       99995  2147-02-08 00:00:00  2147-02-09 00:00:00
# 4156396       99995  2147-02-08 00:00:00  2147-02-09 00:00:00
# 4156397       99995  2147-02-08 00:00:00  2147-02-09 00:00:00
# 4156399       99995  2147-02-08 00:00:00  2147-02-09 00:00:00
# 4156404       98864  2167-12-15 00:00:00  2167-12-16 00:00:00
# 4156405       98864  2167-12-15 00:00:00  2167-12-16 00:00:00
# 4156407       98864  2167-12-16 00:00:00  2167-12-17 00:00:00
# 4156408       98864  2167-12-16 00:00:00  2167-12-17 00:00:00
# 4156409       98864  2167-12-16 00:00:00  2167-12-17 00:00:00
# 4156410       98864  2167-12-16 00:00:00  2167-12-17 00:00:00
# 4156415       98883  2102-01-30 00:00:00  2102-01-31 00:00:00
# 4156416       98883  2102-01-30 00:00:00  2102-01-31 00:00:00
# 4156417       98883  2102-01-30 00:00:00  2102-01-31 00:00:00
# 4156418       98883  2102-01-30 00:00:00  2102-01-31 00:00:00
# 4156419       98883  2102-01-30 00:00:00  2102-01-31 00:00:00
# 4156420       98883  2102-01-30 00:00:00  2102-01-31 00:00:00
# 4156421       98883  2102-01-30 00:00:00  2102-01-31 00:00:00
# 4156422       98883  2102-01-30 00:00:00  2102-01-31 00:00:00
# 4156423       98883  2102-01-30 00:00:00  2102-02-01 00:00:00
# 4156427       98883  2102-01-30 00:00:00  2102-02-01 00:00:00
# 4156441       98887  2144-09-06 00:00:00  2144-09-06 00:00:00
# 4156442       98887  2144-09-06 00:00:00  2144-09-06 00:00:00
# 4156443       98887  2144-09-06 00:00:00  2144-09-06 00:00:00
# 4156447       98887  2144-09-06 00:00:00  2144-09-06 00:00:00
#
#                              DRUG                     DRUG_NAME_GENERIC  \
# 2                  Heparin Sodium                                   NaN
# 3                             D5W                                   NaN
# 6                  Heparin Sodium                                   NaN
# 7                             D5W                                   NaN
# 8                  Heparin Sodium                                   NaN
# 10                            D5W                                   NaN
# 16                            D5W                                   NaN
# 17                 Heparin Sodium                                   NaN
# 23                            D5W                                   NaN
# 24                 Heparin Sodium                                   NaN
# 25                  Nitroglycerin                                   NaN
# 38                 Vancomycin HCl                                   NaN
# 39           Iso-Osmotic Dextrose                                   NaN
# 40                  Acetaminophen                Acetaminophen (Rectal)
# 43                 Metoclopramide                    Metoclopramide HCl
# 48             Potassium Chloride                                   NaN
# 49           Nitroprusside Sodium                                   NaN
# 50                  Nitroglycerin                                   NaN
# 51                             SW                                   NaN
# 52                            D5W                                   NaN
# 53                            D5W                                   NaN
# 54                            D5W                                   NaN
# 56                 Heparin Sodium                                   NaN
# 60                 Metoclopramide                    Metoclopramide HCl
# 63                            D5W                                   NaN
# 69                            D5W                                   NaN
# 70                 Heparin Sodium                                   NaN
# 71                Send 500mg Vial                                   NaN
# 72              NEO*IV*Gentamicin                                   NaN
# 73       NEO*IV*Ampicillin Sodium                                   NaN
# ...                           ...                                   ...
# 4156389                Vancomycin                                   NaN
# 4156390                 CefazoLIN                                   NaN
# 4156391      Iso-Osmotic Dextrose                                   NaN
# 4156392                Vancomycin                                   NaN
# 4156393      Iso-Osmotic Dextrose                                   NaN
# 4156394      Iso-Osmotic Dextrose                                   NaN
# 4156395             Sterile Water                                   NaN
# 4156396      Iso-Osmotic Dextrose                                   NaN
# 4156397                 CefazoLIN                                   NaN
# 4156399        Potassium Chloride                                   NaN
# 4156404             Sterile Water                                   NaN
# 4156405        Potassium Chloride                                   NaN
# 4156407        Potassium Chloride                                   NaN
# 4156408        Potassium Chloride                                   NaN
# 4156409        Potassium Chloride                                   NaN
# 4156410             Sterile Water                                   NaN
# 4156415                       Bag                                   NaN
# 4156416                       Bag                                   NaN
# 4156417                       Bag                                   NaN
# 4156418      0.9% Sodium Chloride                                   NaN
# 4156419      0.9% Sodium Chloride                                   NaN
# 4156420      0.9% Sodium Chloride                                   NaN
# 4156421                        SW                                   NaN
# 4156422                        SW                                   NaN
# 4156423                   Insulin               Insulin - Sliding Scale
# 4156427   Influenza Virus Vaccine  Influenza Virus Vaccine *Latex Free*
# 4156441               5% Dextrose                                   NaN
# 4156442  HYDROmorphone (Dilaudid)                         HYDROmorphone
# 4156443  HYDROmorphone (Dilaudid)                         HYDROmorphone
# 4156447  HYDROmorphone (Dilaudid)                         HYDROmorphone
#
#                  NDC    ROUTE
# 2        00338055002       IV
# 3                  0       IV
# 6        00338055002       IV
# 7                  0       IV
# 8        00338055002       IV
# 10                 0       IV
# 16                 0       IV
# 17       00338055002       IV
# 23                 0       IV
# 24       00074779362       IV
# 25       00074148402  IV DRIP
# 38       00002735501       IV
# 39                 0       IV
# 40       00713016550       PR
# 43       00031670972       IV
# 48       00338070341       IV
# 49       00074302401  IV DRIP
# 50       00074148402  IV DRIP
# 51                 0       IV
# 52       00338001702  IV DRIP
# 53       00338001702  IV DRIP
# 54                 0  IV DRIP
# 56       00338055002       IV
# 60       00904107061       PO
# 63                 0       IV
# 69                 0       IV
# 70       00338055002       IV
# 71                 0       IV
# 72       00641039425       IV
# 73       63323038810       IV
# ...              ...      ...
# 4156389  00338355248       IV
# 4156390  00264310311       IV
# 4156391            0       IV
# 4156392  00338355248       IV
# 4156393            0       IV
# 4156394            0       IV
# 4156395            0       IV
# 4156396            0       PB
# 4156397  00264310311       PB
# 4156399  00338070341       IV
# 4156404            0       IV
# 4156405  00338070341       IV
# 4156407  00338070341       IV
# 4156408  00338070341       IV
# 4156409  00338070341       IV
# 4156410            0       IV
# 4156415            0       IV
# 4156416            0       IV
# 4156417            0       IV
# 4156418  00338004904       IV
# 4156419  00338004902       IV
# 4156420  00338004902       IV
# 4156421            0       IV
# 4156422            0       IV
# 4156423            0       SC
# 4156427  33332001001       IM
# 4156441            0       IV
# 4156442  61553020648    IVPCA
# 4156443  61553020648    IVPCA
# 4156447  61553020648    IVPCA
#
# [2172174 rows x 7 columns]

# %% [markdown]
# ### Remove duplicate drugs (Including drugs sometimes have NDC but not in other time)

# %%
mimic_drug_df = pres_df[['DRUG','NDC']].drop_duplicates()
mimic_drug_df.count()
# Out:
# DRUG    9211
# NDC     8065
# dtype: int64

# %%
mimic_drug_counts = mimic_drug_df.groupby('DRUG',as_index=False).count().rename(columns={'NDC':'NDC_count'})
mimic_drug_counts.head()
# Out:
#                            DRUG  NDC_count
# 0                                        0
# 1   Cabergoline     ( Dostinex)          0
# 2                     Symbicort          0
# 3            Zaditor Ophthalmic          0
# 4     *IND* Pexelizumab/Placebo          1

# %%
mimic_drug_df = aa.left_join(mimic_drug_df, mimic_drug_counts,'DRUG')
mimic_drug_df.head()
# Out:
#              DRUG          NDC  NDC_count
# 0      Tacrolimus  00469061711          9
# 1        Warfarin  00056017275          7
# 2  Heparin Sodium  00338055002          9
# 3             D5W            0         12
# 4      Furosemide  00054829725         17

# %%
mimic_drug_counts['NDC_L'] = mimic_drug_df.groupby('DRUG',as_index=False)['NDC'].apply(list)
## Write mimic3 drugs with NDC code lists into files

# %% [markdown]
# ### mapping drugs(ndc, names) to CIDs

# %%
mimic_drug_counts=pd.read_csv(write_prefix%'mimic_drugs')
mimic_drug_counts.head()
# Out:
#                            DRUG  NDC_count            NDC_L
# 0   Cabergoline     ( Dostinex)          0            [nan]
# 1                     Symbicort          0            [nan]
# 2            Zaditor Ophthalmic          0            [nan]
# 3     *IND* Pexelizumab/Placebo          1            ['0']
# 4                           *NF          1  ['63824000840']

# %%
# mimic_drug_counts['DRUG_len'] = mimic_drug_counts['DRUG'].apply(len)

# %%
# mimic_drug_counts

# %%
class drug_mapping():
    
    def list_notna(self, L):
        return list(filter(None, L))
    
    def drug_keywords(self, drug):
        drug = drug.strip()
        ## remove percentage value(interger and float) and **[w]**
        ill_regex = '[(-.0-9)(\d)]+%|\*+.*?\*+|\*+[a-zA-Z]+'
        drug = re.sub(ill_regex, "", drug)
        
        ## Extract terms within brackets
        bracket_re = '\(.*?\)'
        bracket_terms = re.findall(bracket_re, drug)
        bracket_terms = [re.sub('[\(\)]',"",i).strip() for i in bracket_terms]
        bracket_terms = [('_').join(re.sub(' +', "",i).split(' ')) for i in bracket_terms]
        drug = re.sub(bracket_re, "", drug).strip()
        
        ## split by " " and "/"
        drug_terms = re.split(' +|\/', drug)
        
        ## reverse drug whole name
        if(len(drug_terms)>1):
            drug = ('_').join(drug_terms)
            reverse_drug = ('_').join(drug_terms[1:]+[drug_terms[0]])
            if(len(drug_terms)>2):
                back_reverse_drug = ('_').join([drug_terms[-1]]+drug_terms[:-1])
                reverse_drug = [reverse_drug, back_reverse_drug]
            else: reverse_drug = [reverse_drug]
            return self.list_notna([drug] + bracket_terms + reverse_drug), \
                        self.list_notna(drug_terms)
        else: 
            return self.list_notna([drug] + bracket_terms), []
    
    def search_CID_bydrugs(self, drugs):
        pubchem_api_1 = 'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/%s/cids/JSON'
        if(drugs):
            all_results = []
            for drug in drugs:
                response = requests.get(pubchem_api_1%drug)
                if(response.status_code!=404):
                    try:
                        results = response.json()['IdentifierList']['CID']
                    except:
                        continue
                    all_results = all_results + results
            all_results = list(set(all_results))
            return all_results[:5]
                
    
    def search_CID_byterms(self, drug_terms):
        pubchem_api_2 = 'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/%s/cids/JSON?name_type=word'

        ## Only remain 2 results with the least results
        min2_results = {}
        num_results = 0
        if(drug_terms):
            for term in drug_terms:
                response = requests.get(pubchem_api_2%term)
                if(response.status_code!=404):
                    min2_result = {}
                    try:
                        results = response.json()['IdentifierList']['CID']   
                    except:
                        continue
                    if(num_results<2):             
                        min2_result['CID'] = results
                        min2_result['len'] = len(results)
                        min2_results[term] = min2_result
                        num_results += 1
                    else: 
                        min2_terms = min2_results.keys()
                        min2_len = {min2_results[key]['len']:key for key in min2_terms}
                        new_len = len(results)
                        max_len = max(min2_len.keys())
                        if(new_len < max_len):
                            min2_results.pop(min2_len[max_len])
                            min2_result['CID'] = results
                            min2_result['len'] = new_len
                            min2_results[term] = min2_result
        else: return []                   
        results_len= len(min2_results)
        if(results_len==0): 
            return []
        elif(results_len==1): 
            return min2_results[list(min2_results.keys())[0]]['CID'][:5]
        else: 
            keys = list(min2_results.keys())
            re1 = min2_results[keys[0]]['CID'][:3]
            re2 = min2_results[keys[1]]['CID'][:3]
            finals = list(set(re1).intersection(set(re2)))
            if(len(finals)==0):
                finals = re1 + re2
            return finals[:5]
    
    def search_ingredient_byndc(self, ndc_code):
        fda_ndc_api = 'https://api.fda.gov/drug/ndc.json?search=product_ndc:"%s"'
        response = requests.get(fda_ndc_api%ndc_code)
        try:
            ingredient = response.json()['results'][0]['active_ingredients'][0]['name']
            return ingredient
        except:
            return ''
        
    
    def get_ingredients_byndc(self, drug_ndc):
        comma_re = '\'\d+\''
        ndc_L = re.findall(comma_re, drug_ndc)
        ndc_L = [s.replace('\'','') for s in ndc_L]
        
        ndc_len = len(drug_ndc)
        if(not ndc_L): return []
        elif(ndc_len==1 and ndc_L[0]=='0'):
            return []
        else:
            ndc_codes = []
            for ndc in ndc_L:
                ## Match three kinds of ndc format
                if(ndc[0]=='0'):
                    ## 442
                    ndc_codes = ndc_codes + [('-').join([ndc[1:5], ndc[5:9]])]
                if(ndc[5]=='0'):
                    ## 532
                    ndc_codes = ndc_codes + [('-').join([ndc[0:5],ndc[6:9]])]
                if(ndc[9]=='0'):
                    ## 541
                    ndc_codes = ndc_codes + [('-').join([ndc[0:5],ndc[5:9]])]
            ingredients = [self.search_ingredient_byndc(ndc_code) for ndc_code in ndc_codes]
            ingredients = self.list_notna(ingredients)
            return ingredients
#             return ndc_codes
                    
            
    
    def get_CID_by_name(self, drug):
        drugs, terms = self.drug_keywords(drug)
        first_re = self.search_CID_bydrugs(drugs)
        if(first_re):
            return first_re
        else:
            if(not terms): terms=drugs
            second_re = self.search_CID_byterms(terms)
            return second_re
    
    def list_flattern(self, l):
        flatten_L = [item for sublist in l for item in sublist]
        return flatten_L
    
    def get_CID(self, drug_name, drug_ndc):
        ## first search ingredients and then search ICD
        ingredient_L = self.search_ingredient_byndc(drug_ndc)
        cid_L = self.list_flattern([self.get_CID_by_name(ingred) for ingred in ingredient_L])
        
        if(not cid_L):
            cid_L = self.get_CID_by_name(drug_name)
        return cid_L

# %%
dm = drug_mapping()
# ndc = "['00002831501']"
# ndc_L = dm.get_ingredients_byndc(ndc)
# ndc_L
# mimic_drug_counts_p1 = mimic_drug_counts[:1500]

# %%
mimic_drug_counts[:10].apply(lambda row: dm.get_CID(row['DRUG'], row['NDC_L']), axis=1)
# Out:
# 0                                              [54746]
# 1                                    [56841116, 40000]
# 2              [5282408, 3827, 71749703, 298, 7018721]
# 3                    [5073, 5284627, 444795, 54671203]
# 4                                                   []
# 5                                              [68844]
# 6                                                   []
# 7                                       [60172, 60871]
# 8                                                   []
# 9    [135401907, 135534565, 135407110, 23675735, 23...
# dtype: object

# %%
mimic_drug_counts[:10]
# Out:
#                            DRUG  NDC_count            NDC_L
# 0   Cabergoline     ( Dostinex)          0            [nan]
# 1                     Symbicort          0            [nan]
# 2            Zaditor Ophthalmic          0            [nan]
# 3     *IND* Pexelizumab/Placebo          1            ['0']
# 4                           *NF          1  ['63824000840']
# 5      *NF BRINZOLAMIDE (AZOPT)          0            [nan]
# 6                *NF* Abatacept          1  ['00003218710']
# 7       *NF* Adefovir (HepSera)          0            [nan]
# 8              *NF* Alemtuzumab          1  ['50419035510']
# 9       *NF* Allopurinol Sodium          1  ['59730560101']

# %%
('-').join([ndc[1:5], ndc[5:9],ndc[9:]])
# Out:
# '0002-8215-01'

# %%
drug_ndc = "[nan]"
comma_re = '\'\d+\''
ndc_L = re.findall(comma_re, drug_ndc)
ndc_L = [s.replace('\'','') for s in ndc_L]

# %%
ndc_L
# Out:
# []

# %%
dm.drug_keywords('~ <IND> Defibrotide')
# Out:
# (['~_<IND>_Defibrotide', '<IND>_Defibrotide_~', 'Defibrotide_~_<IND>'],
#  ['~', '<IND>', 'Defibrotide'])

# %%
mimic_drug_counts_p1['CID']=mimic_drug_counts_p1['DRUG'].apply(dm.get_ICD_by_name)
aa.write2file('mimic_drugs_CID_p1')

# %%
p = '*NF BRINZOLAMIDE (AZOPT) AB'
ill_regex = '[(-.0-9)(\d)]+%|\*.*?\*|\*+[a-zA-Z]+'
t = re.sub(ill_regex, "", p)
print(t)
# Out:
#  BRINZOLAMIDE (AZOPT) AB

# %%
## apply on drug_counts
mimic_drug_counts['DRUG'][:10].apply(dm.get_ICD_by_name)
# Out:
# ['Cabergoline', 'Dostinex']
# [54746]
# ['Symbicort']
# [56841116, 40000]
# ['Zaditor_Ophthalmic', 'Ophthalmic_Zaditor']
# [5282408, 3827, 71749703, 298, 7018721]
# ['Pexelizumab_Placebo', 'Placebo_Pexelizumab']
# [5073, 5284627, 444795, 54671203]
# []
# []
# ['BRINZOLAMIDE', 'AZOPT']
# [68844]
# ['Abatacept']
# []
# ['Adefovir', 'HepSera']
# [60172, 60871]
# ['Alemtuzumab']
# []
# ['Allopurinol_Sodium', 'Sodium_Allopurinol']
# [23675735, 23665884, 16684434, 135401907, 135534565]
# 0                                              [54746]
# 1                                    [56841116, 40000]
# 2              [5282408, 3827, 71749703, 298, 7018721]
# 3                    [5073, 5284627, 444795, 54671203]
# 4                                                   []
# 5                                              [68844]
# 6                                                   []
# 7                                       [60172, 60871]
# 8                                                   []
# 9    [23675735, 23665884, 16684434, 135401907, 1355...
# Name: DRUG, dtype: object

# %%
mimic_drug_counts[:10]
# Out:
#                            DRUG  NDC_count            NDC_L
# 0   Cabergoline     ( Dostinex)          0            [nan]
# 1                     Symbicort          0            [nan]
# 2            Zaditor Ophthalmic          0            [nan]
# 3     *IND* Pexelizumab/Placebo          1            ['0']
# 4                           *NF          1  ['63824000840']
# 5      *NF BRINZOLAMIDE (AZOPT)          0            [nan]
# 6                *NF* Abatacept          1  ['00003218710']
# 7       *NF* Adefovir (HepSera)          0            [nan]
# 8              *NF* Alemtuzumab          1  ['50419035510']
# 9       *NF* Allopurinol Sodium          1  ['59730560101']

# %%
out

# %%
a[a['DRUG_NAME_GENERIC'].notna()]
# Out:
#          SUBJECT_ID            STARTDATE              ENDDATE  \
# 40               13  2167-01-09 00:00:00  2167-01-12 00:00:00
# 43               13  2167-01-09 00:00:00  2167-01-12 00:00:00
# 60                6  2175-06-14 00:00:00  2175-06-15 00:00:00
# 112               4  2191-03-16 00:00:00  2191-03-16 00:00:00
# 116               4  2191-03-16 00:00:00  2191-03-16 00:00:00
# 123               4  2191-03-16 00:00:00  2191-03-19 00:00:00
# 131               4  2191-03-16 00:00:00  2191-03-23 00:00:00
# 134               4  2191-03-16 00:00:00  2191-03-23 00:00:00
# 141               4  2191-03-17 00:00:00  2191-03-20 00:00:00
# 147               4  2191-03-18 00:00:00  2191-03-23 00:00:00
# 148               4  2191-03-19 00:00:00  2191-03-20 00:00:00
# 153               4  2191-03-20 00:00:00  2191-03-20 00:00:00
# 155               4  2191-03-20 00:00:00  2191-03-22 00:00:00
# 159               4  2191-03-21 00:00:00  2191-03-22 00:00:00
# 162               4  2191-03-22 00:00:00  2191-03-23 00:00:00
# 164               4  2191-03-22 00:00:00  2191-03-23 00:00:00
# 165               4  2191-03-22 00:00:00  2191-03-23 00:00:00
# 166               4  2191-03-22 00:00:00  2191-03-23 00:00:00
# 173               6  2175-05-30 00:00:00  2175-06-01 00:00:00
# 179               6  2175-05-30 00:00:00  2175-06-15 00:00:00
# 187               6  2175-05-30 00:00:00  2175-06-15 00:00:00
# 204               6  2175-06-01 00:00:00  2175-06-14 00:00:00
# 221               6  2175-06-02 00:00:00  2175-06-15 00:00:00
# 256               6  2175-06-06 00:00:00  2175-06-07 00:00:00
# 259               6  2175-06-07 00:00:00  2175-06-08 00:00:00
# 261               6  2175-06-07 00:00:00  2175-06-14 00:00:00
# 264               6  2175-06-08 00:00:00  2175-06-15 00:00:00
# 286              12  2104-08-08 00:00:00  2104-08-11 00:00:00
# 295              12  2104-08-09 00:00:00  2104-08-14 00:00:00
# 314              12  2104-08-11 00:00:00  2104-08-14 00:00:00
# ...             ...                  ...                  ...
# 4156222       98931  2166-05-04 00:00:00  2166-05-05 00:00:00
# 4156223       98931  2166-05-04 00:00:00  2166-05-05 00:00:00
# 4156232       98931  2166-05-04 00:00:00  2166-05-08 00:00:00
# 4156242       98931  2166-05-04 00:00:00  2166-05-08 00:00:00
# 4156244       98931  2166-05-05 00:00:00  2166-05-06 00:00:00
# 4156252       98959  2142-01-06 00:00:00  2142-01-09 00:00:00
# 4156253       98959  2142-01-06 00:00:00  2142-01-09 00:00:00
# 4156258       98959  2142-01-06 00:00:00  2142-01-09 00:00:00
# 4156271       98994  2137-08-12 00:00:00  2137-08-13 00:00:00
# 4156282       98994  2137-08-13 00:00:00  2137-08-14 00:00:00
# 4156285       98994  2137-08-14 00:00:00  2137-08-15 00:00:00
# 4156315       99011  2106-06-13 00:00:00  2106-06-17 00:00:00
# 4156338       99017  2176-07-08 00:00:00  2176-07-10 00:00:00
# 4156345       99017  2176-07-08 00:00:00  2176-07-10 00:00:00
# 4156346       99017  2176-07-08 00:00:00  2176-07-10 00:00:00
# 4156353       99957  2157-02-21 00:00:00  2157-02-23 00:00:00
# 4156355       99991  2185-01-04 00:00:00  2185-01-05 00:00:00
# 4156361       99992  2144-07-25 00:00:00  2144-07-28 00:00:00
# 4156363       99992  2144-07-25 00:00:00  2144-07-28 00:00:00
# 4156372       99992  2144-07-26 00:00:00  2144-07-27 00:00:00
# 4156373       99992  2144-07-26 00:00:00  2144-07-27 00:00:00
# 4156375       99992  2144-07-26 00:00:00  2144-07-28 00:00:00
# 4156377       99992  2144-07-27 00:00:00  2144-07-27 00:00:00
# 4156380       99992  2144-07-27 00:00:00  2144-07-28 00:00:00
# 4156383       99992  2144-07-27 00:00:00  2144-07-28 00:00:00
# 4156423       98883  2102-01-30 00:00:00  2102-02-01 00:00:00
# 4156427       98883  2102-01-30 00:00:00  2102-02-01 00:00:00
# 4156442       98887  2144-09-06 00:00:00  2144-09-06 00:00:00
# 4156443       98887  2144-09-06 00:00:00  2144-09-06 00:00:00
# 4156447       98887  2144-09-06 00:00:00  2144-09-06 00:00:00
#
#                                       DRUG  \
# 40                           Acetaminophen
# 43                          Metoclopramide
# 60                          Metoclopramide
# 112                                Insulin
# 116                                 Lantus
# 123                                Insulin
# 131                                Heparin
# 134                             Ranitidine
# 141                                 Lantus
# 147                Didanosine Chewable Tab
# 148                                Insulin
# 153                                 Lantus
# 155                                Insulin
# 159                                Insulin
# 162                                Insulin
# 164                                 Lantus
# 165                            Clindamycin
# 166                                Insulin
# 173                       Morphine Sulfate
# 179                                Insulin
# 187      Heparin Flush CVL  (100 units/ml)
# 204                         Metoclopramide
# 221                              Albuterol
# 256                              Bisacodyl
# 259                              Bisacodyl
# 261                       Morphine Sulfate
# 264                              Bisacodyl
# 286                                Heparin
# 295                       Morphine Sulfate
# 314                                Heparin
# ...                                    ...
# 4156222                            Insulin
# 4156223                            Insulin
# 4156232                          Bisacodyl
# 4156242                            Heparin
# 4156244                            Insulin
# 4156252        Heparin Flush (10 units/ml)
# 4156253            Ipratropium Bromide MDI
# 4156258                   Milk of Magnesia
# 4156271                     ValGANCIclovir
# 4156282                 Methylprednisolone
# 4156285                 Methylprednisolone
# 4156315        Heparin Flush (10 units/ml)
# 4156338        Pneumococcal Vac Polyvalent
# 4156345            Ipratropium Bromide MDI
# 4156346                            Heparin
# 4156353                            Heparin
# 4156355        Potassium Chloride (Powder)
# 4156361                            Insulin
# 4156363        Heparin Flush (10 units/ml)
# 4156372                 Methylprednisolone
# 4156373                 Methylprednisolone
# 4156375                 Methylprednisolone
# 4156377                  Calcium Carbonate
# 4156380                  Calcium Carbonate
# 4156383                 Methylprednisolone
# 4156423                            Insulin
# 4156427            Influenza Virus Vaccine
# 4156442           HYDROmorphone (Dilaudid)
# 4156443           HYDROmorphone (Dilaudid)
# 4156447           HYDROmorphone (Dilaudid)
#
#                             DRUG_NAME_GENERIC          NDC  ROUTE
# 40                     Acetaminophen (Rectal)  00713016550     PR
# 43                         Metoclopramide HCl  00031670972     IV
# 60                         Metoclopramide HCl  00904107061     PO
# 112                          Insulin Glargine  00088222033     SC
# 116                          Insulin Glargine  00088222033     SC
# 123                          Insulin Glargine  00088222033     SC
# 131                            Heparin Sodium  00641040025     SC
# 134                            Ranitidine HCl  00781188313     PO
# 141                          Insulin Glargine  00088222033     SC
# 147                                Didanosine  00087665201     PO
# 148                          Insulin Glargine  00088222033     SC
# 153                          Insulin Glargine  00088222033     SC
# 155                          Insulin Glargine  00088222033     SC
# 159                         Insulin Human NPH  00002831501     SC
# 162                         Insulin Human NPH  00002831501     SC
# 164                          Insulin Glargine  00088222033     SC
# 165                           Clindamycin HCl  51079059820     PO
# 166                          Insulin Glargine  00088222033     SC
# 173                              Morphine PCA  00338268975  IVPCA
# 179                   Insulin - Sliding Scale            0     SC
# 187                             Heparin Flush  64253033335     IV
# 204                        Metoclopramide HCl  60977045101     IV
# 221                         Albuterol Inhaler  00172439018     IH
# 256                        Bisacodyl (Rectal)  51079055271     PR
# 259                        Bisacodyl (Rectal)  51079055271     PR
# 261                  Morphine Sulfate (2-4mg)  00074176230     IV
# 264                        Bisacodyl (Rectal)  51079055271     PR
# 286                            Heparin Sodium  00641040025     SC
# 295                  Morphine Sulfate (1-5mg)  00074125901     SC
# 314                            Heparin Sodium  00641040025     SC
# ...                                       ...          ...    ...
# 4156222                     Insulin Human NPH  00002831501     SC
# 4156223               Insulin - Sliding Scale            0     SC
# 4156232                    Bisacodyl (Rectal)  00574705050     PR
# 4156242                        Heparin Sodium  63323026201     SC
# 4156244               Insulin - Sliding Scale            0     SC
# 4156252           Heparin Flush (10 Units/mL)  08290036005     IV
# 4156253               Ipratropium Bromide HFA  00597008717     IH
# 4156258                      Milk Of Magnesia  00121043130     PO
# 4156271             ValGANCIclovir Suspension  00004003822     PO
# 4156282        MethylPREDNISolone Sodium Succ  00009011319     IV
# 4156285        MethylPREDNISolone Sodium Succ  00009011319     IV
# 4156315           Heparin Flush (10 Units/mL)  08290036005     IV
# 4156338           PNEUMOcoccal Vac Polyvalent  00006473900     IM
# 4156345               Ipratropium Bromide HFA  00597008717     IH
# 4156346                        Heparin Sodium  63323026201     SC
# 4156353                        Heparin Sodium  63323026201     SC
# 4156355                    Potassium Chloride  58177020211  PO/NG
# 4156361               Insulin - Sliding Scale            0     SC
# 4156363           Heparin Flush (10 Units/mL)  08290036005     IV
# 4156372                    MethylPREDNISolone  66993084225     PO
# 4156373                    MethylPREDNISolone  00009004902     PO
# 4156375                    MethylPREDNISolone  66993084225     PO
# 4156377              Calcium Carbonate (Tums)  66553000401  PO/NG
# 4156380              Calcium Carbonate (Tums)  66553000401  PO/NG
# 4156383                    MethylPREDNISolone  00009004902     PO
# 4156423               Insulin - Sliding Scale            0     SC
# 4156427  Influenza Virus Vaccine *Latex Free*  33332001001     IM
# 4156442                         HYDROmorphone  61553020648  IVPCA
# 4156443                         HYDROmorphone  61553020648  IVPCA
# 4156447                         HYDROmorphone  61553020648  IVPCA
#
# [509185 rows x 7 columns]

# %%
# Out:
# array([11,  1,  3])

# %%
# Out:
# array(['0'], dtype=object)

# %%
# Out:
# array([nan], dtype=object)

# %%
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTDATE  \
# 683    2981776          11   194540         NaN  2178-05-10 00:00:00
# 686    2981777          11   194540         NaN  2178-05-10 00:00:00
# 10011  1040299         124   172461         NaN  2160-07-09 00:00:00
# 10012  1040300         124   172461         NaN  2160-07-09 00:00:00
# 10015  1040297         124   172461         NaN  2160-07-09 00:00:00
#
#                    ENDDATE DRUG_TYPE            DRUG DRUG_NAME_POE  \
# 683    2178-05-10 00:00:00      MAIN       Melatonin     Melatonin
# 686    2178-05-11 00:00:00      MAIN       Melatonin     Melatonin
# 10011  2160-07-10 00:00:00      MAIN      Famotidine           NaN
# 10012  2160-07-10 00:00:00      MAIN       Cefazolin           NaN
# 10015  2160-07-10 00:00:00      MAIN  Heparin Sodium           NaN
#
#       DRUG_NAME_GENERIC FORMULARY_DRUG_CD  \
# 683           Melatonin               NaN
# 686           Melatonin               NaN
# 10011               NaN          FAMO20PM
# 10012               NaN            CEFA1F
# 10015               NaN        HEPAPREMIX
#
#                                        GSN  NDC           PROD_STRENGTH  \
# 683    024665 041568 044488 043811 026076   NaN                    1 mg
# 686    024665 041568 044488 043811 026076   NaN                    1 mg
# 10011                               021732  NaN         20mg Premix Bag
# 10012                               009061  NaN             1g Froz.Bag
# 10015                               006522  NaN  25,000 unit Premix Bag
#
#       DOSE_VAL_RX DOSE_UNIT_RX FORM_VAL_DISP FORM_UNIT_DISP ROUTE  NDC_length
# 683            11           mg            11            TAB  ORAL           3
# 686             1           mg             1            TAB  ORAL           3
# 10011          20           mg             1            BAG    IV           3
# 10012           1           gm             1            BAG    IV           3
# 10015       25000         UNIT             1            BAG    IV           3

# %%
del pres_df_1, pres_df_3

# %% [markdown]
# ## SIDE EFFECTS

# %%
drug_indication_df = pd.read_csv('/data/liu/ade/SIDER_4/indications.tsv', sep='\t', header=0)
drug_indication_df.head()
# del drug_indication_df
# Out:
#   drugbank_id drugbank_name  pubchem_id stitch_id_flat umls_cui_from_label  \
# 0     DB00014     Goserelin       47725   CID100047725            C0002871
# 1     DB00014     Goserelin       47725   CID100047725            C0006142
# 2     DB00014     Goserelin       47725   CID100047725            C0006826
# 3     DB00014     Goserelin       47725   CID100047725            C0014175
# 4     DB00014     Goserelin       47725   CID100047725            C0025323
#
#              method                  concept_name meddra_type  \
# 0      text_mention                        Anemia          PT
# 1    NLP_indication  Malignant neoplasm of breast          PT
# 2  NLP_precondition           Malignant Neoplasms          PT
# 3    NLP_indication                 Endometriosis          PT
# 4      text_mention                   Menorrhagia          PT
#
#   umls_cui_from_meddra         meddra_name
# 0             C0002871             Anaemia
# 1             C0006142       Breast cancer
# 2             C0006826  Neoplasm malignant
# 3             C0014175       Endometriosis
# 4             C0025323         Menorrhagia

# %%
drug_indication_df[drug_indication_df['drugbank_name']=='Tacrolimus'].head()
# Out:
#      drugbank_id drugbank_name  pubchem_id stitch_id_flat umls_cui_from_label  \
# 8247     DB00864    Tacrolimus        5372   CID100005372            C0003862
# 8248     DB00864    Tacrolimus        5372   CID100005372            C0003862
# 8249     DB00864    Tacrolimus        5372   CID100005372            C0003864
# 8250     DB00864    Tacrolimus        5372   CID100005372            C0003873
# 8251     DB00864    Tacrolimus        5372   CID100005372            C0003873
#
#               method          concept_name meddra_type umls_cui_from_meddra  \
# 8247  NLP_indication            Arthralgia          PT             C0948594
# 8248  NLP_indication            Arthralgia          PT             C0003862
# 8249    text_mention             Arthritis          PT             C0003864
# 8250  NLP_indication  Rheumatoid Arthritis          PT             C0003873
# 8251  NLP_indication  Rheumatoid Arthritis          PT             C0003864
#
#                      meddra_name
# 8247  Musculoskeletal discomfort
# 8248                  Arthralgia
# 8249                   Arthritis
# 8250        Rheumatoid arthritis
# 8251                   Arthritis

# %%
side_effect_df = pd.read_csv('/data/liu/ade/SIDER_4/side-effects.tsv', sep='\t', header=0)
side_effect_df.head()
# Out:
#   drugbank_id                                      drugbank_name  \
# 0     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 1     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 2     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 3     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 4     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
#
#   umls_cui_from_meddra          side_effect_name
# 0             C0000729          Abdominal cramps
# 1             C0000737            Abdominal pain
# 2             C0232492      Abdominal pain upper
# 3             C0740651         Abdominal symptom
# 4             C0877331  Abnormal clotting factor

# %%
side_effect_df[side_effect_df['drugbank_id']=='DB00864'].head()
# Out:
#        drugbank_id drugbank_name umls_cui_from_meddra      side_effect_name
# 133938     DB00864    Tacrolimus             C1291077    Abdominal bloating
# 133939     DB00864    Tacrolimus             C0000731  Abdominal distension
# 133940     DB00864    Tacrolimus             C0000737        Abdominal pain
# 133941     DB00864    Tacrolimus             C0234458       Abnormal dreams
# 133942     DB00864    Tacrolimus             C3665386       Abnormal vision

# %%
len(side_effect_df['drugbank_name'].unique())
# Out:
# 1223

# %%
len(pres_df['DRUG'].unique())
# Out:
# 4206

# %% [markdown]
# ## Match drugs in DrugBank and MIMIC3 by names

# %%
# drugbank_df = pd.read_csv('/data/liu/ade/SIDER_4/spider_drugbank.txt', sep='\t')
## Solve text with different number of columns 
def read_from_txt(filepath,cols,split='\t\t'):
    f=open(filepath,"r")
    lines=f.readlines()
    result=[]
    for x in lines:
        result.append(x.split(split)[:cols])
    f.close()
    return result

# drugbank_list = read_from_txt('/data/liu/ade/SIDER_4/spider_drugbank.txt',2)
drugbank_list = pd.read_csv('/data/liu/ade/SIDER_4/drugbank.tsv', header=0, sep='\t')
drugbank_list[:5]

pres_drugs = pres_df[['DRUG','NDC']].drop_duplicates()
# pres_drugs = pres_drugs[pres_drugs['NDC'].notna()]
aa.write2file(pres_drugs,'mimic_drugs')

bank_drugs = drugbank_list[['drugbank_id','name']].drop_duplicates()
aa.write2file(pres_drugs,'bank_drugs')

# sider_drugs = side_effect_df[['drugbank_id','drugbank_name']].drop_duplicates()
aa.write2file(pres_drugs,'sider_drugs')

# %%
pres_drugs.head()
# Out:
#              DRUG          NDC
# 0      Tacrolimus  00469061711
# 1        Warfarin  00056017275
# 2  Heparin Sodium  00338055002
# 3             D5W            0
# 4      Furosemide  00054829725

# %%
pres_drugs = pd.read_csv(write_prefix%'mimic_drugs', header=0, sep=',',dtype={'NDC': str})
pres_drugs.head()
# Out:
#              DRUG          NDC
# 0      Tacrolimus  00469061711
# 1        Warfarin  00056017275
# 2  Heparin Sodium  00338055002
# 3             D5W            0
# 4      Furosemide  00054829725

# %%
import requests
def get_unii(drug_name):
    fda_api = 'https://api.fda.gov/drug/label.json?search=openfda.generic_name:%s&limit=1' % drug_name
    r = requests.get(fda_api)
    try:
        return set(r.json()['results'][0]['openfda']['unii'])
    except:
        print("Cannot find the drug %s in FDA dataset." % drug_name)
        return np.nan

# %%
## Search unii codes for drugs in MIMIC3
pres_drugs['UNII'] = pres_drugs['DRUG'].apply(get_unii)
# Out:
# Cannot find the drug D5W in FDA dataset.
# Cannot find the drug Zolpidem Tartrate in FDA dataset.
# Cannot find the drug Midazolam HCl in FDA dataset.
# Cannot find the drug Nitroglycerin SL in FDA dataset.
# Cannot find the drug Vancomycin HCl in FDA dataset.
# Cannot find the drug Iso-Osmotic Dextrose in FDA dataset.
# Cannot find the drug SW in FDA dataset.
# Cannot find the drug D5W in FDA dataset.
# Cannot find the drug Valganciclovir HCl in FDA dataset.
# Cannot find the drug Send 500mg Vial in FDA dataset.
# Cannot find the drug NEO*IV*Gentamicin in FDA dataset.
# Cannot find the drug NEO*IV*Ampicillin Sodium in FDA dataset.
# Cannot find the drug Syringe (Neonatal) *D5W* in FDA dataset.
# Cannot find the drug Labetalol HCl in FDA dataset.
# Cannot find the drug NS in FDA dataset.
# Cannot find the drug Soln. in FDA dataset.
# Cannot find the drug Hydralazine HCl in FDA dataset.
# Cannot find the drug *NF* Nicardipine HCl IV in FDA dataset.
# Cannot find the drug NEO*IV*Gentamicin in FDA dataset.
# Cannot find the drug Lantus in FDA dataset.
# Cannot find the drug Vancomycin HCl in FDA dataset.
# Cannot find the drug NS in FDA dataset.
# Cannot find the drug Loperamide HCl in FDA dataset.
# Cannot find the drug D5W in FDA dataset.
# Cannot find the drug 1/2 NS in FDA dataset.
# Cannot find the drug D5 1/2NS in FDA dataset.
# Cannot find the drug Diphenhydramine HCl in FDA dataset.
# Cannot find the drug Sulfameth/Trimethoprim SS in FDA dataset.
# Cannot find the drug Heparin Flush CVL  (100 units/ml) in FDA dataset.
# Cannot find the drug Methylprednisolone Na Succ. in FDA dataset.
# Cannot find the drug NS in FDA dataset.
# Cannot find the drug Dextrose 5% in FDA dataset.
# Cannot find the drug Fentanyl Citrate in FDA dataset.
# Cannot find the drug Diphenhydramine HCl in FDA dataset.
# Cannot find the drug Clonidine HCl in FDA dataset.
# Cannot find the drug NS in FDA dataset.
# Cannot find the drug Fluocinolone 0.025% Cream in FDA dataset.
# Cannot find the drug Piperacillin-Tazobactam Na in FDA dataset.
# Cannot find the drug Moexipril HCl in FDA dataset.
# Cannot find the drug Atorvastatin in FDA dataset.
# Cannot find the drug Normocarb in FDA dataset.
# Cannot find the drug Sterile Water in FDA dataset.
# Cannot find the drug HydrALAZINE HCl in FDA dataset.
# Cannot find the drug HydrALAZINE HCl in FDA dataset.
# Cannot find the drug Amiodarone HCl in FDA dataset.
# Cannot find the drug D5W in FDA dataset.
# Cannot find the drug Amiodarone HCl in FDA dataset.
# Cannot find the drug Phenylephrine HCl in FDA dataset.
# Cannot find the drug Maalox/Benadryl/Lidocaine in FDA dataset.
# Cannot find the drug LR in FDA dataset.
# Cannot find the drug Sodium Chloride 0.9%  Flush in FDA dataset.
# Cannot find the drug Vancomycin HCl in FDA dataset.
# Cannot find the drug Phenylephrine HCl in FDA dataset.
# Cannot find the drug Syringe in FDA dataset.
# Cannot find the drug NS in FDA dataset.
# Cannot find the drug D5W in FDA dataset.
# Cannot find the drug D5W in FDA dataset.
# Cannot find the drug Hydralazine HCl in FDA dataset.
# Cannot find the drug Labetalol HCl in FDA dataset.
# Cannot find the drug Hydralazine HCl in FDA dataset.
# Cannot find the drug NEO*IV*Parenteral Nutrition in FDA dataset.
# Cannot find the drug NEO*IV*Fat Emulsion in FDA dataset.
# Cannot find the drug D10W in FDA dataset.
# Cannot find the drug NEO*PO*Ferrous Sulfate Elixer in FDA dataset.
# Cannot find the drug Tetanus-Diphtheria Toxoids-Td in FDA dataset.
# Cannot find the drug Potassium Chl 20 mEq / 1000 mL D5 1/2 NS in FDA dataset.
# Cannot find the drug Potassium Chl 20 mEq / 1000 mL NS in FDA dataset.
# Cannot find the drug Mannitol 20% in FDA dataset.
# Cannot find the drug Promethazine HCl in FDA dataset.
# Cannot find the drug OxycoDONE (Immediate Release)  in FDA dataset.
# Cannot find the drug traZODONE HCl in FDA dataset.
# Cannot find the drug *NF* Temozolomide in FDA dataset.
# Cannot find the drug *NF* Temozolomide in FDA dataset.
# Cannot find the drug Multivitamins in FDA dataset.
# Cannot find the drug Fentanyl Citrate in FDA dataset.
# Cannot find the drug Atorvastatin in FDA dataset.
# Cannot find the drug Clopidogrel Bisulfate in FDA dataset.
# Cannot find the drug Atorvastatin in FDA dataset.
# Cannot find the drug Acetylcysteine 20% in FDA dataset.
# Cannot find the drug Magnesium Oxide in FDA dataset.
# Cannot find the drug Enalapril Maleate in FDA dataset.
# Cannot find the drug Metoprolol XL in FDA dataset.
# Cannot find the drug Dextrose 50% in FDA dataset.
# Cannot find the drug Rosuvastatin Calcium in FDA dataset.
# Cannot find the drug traZODONE HCl in FDA dataset.
# Cannot find the drug Escitalopram Oxalate in FDA dataset.
# Cannot find the drug Thiamine HCl in FDA dataset.
# Cannot find the drug Maalox/Diphenhydramine/Lidocaine in FDA dataset.
# Cannot find the drug Metoprolol XL in FDA dataset.
# Cannot find the drug Hespan in FDA dataset.
# Cannot find the drug Diovan in FDA dataset.
# Cannot find the drug Diovan in FDA dataset.
# Cannot find the drug D5W in FDA dataset.
# Cannot find the drug Heparin Flush CRRT (5000 Units/mL) in FDA dataset.
# Cannot find the drug Polysaccharide Iron Complex in FDA dataset.
# Cannot find the drug Sertraline HCl in FDA dataset.
# Cannot find the drug Eucerin in FDA dataset.
# Cannot find the drug 0.9% Sodium Chloride in FDA dataset.
# Cannot find the drug 0.9% Sodium Chloride in FDA dataset.
# Cannot find the drug 0.9% Sodium Chloride in FDA dataset.
# Cannot find the drug 5% Dextrose in FDA dataset.
# Cannot find the drug Dextrose 50% in FDA dataset.
# Cannot find the drug Albuterol 0.083% Neb Soln in FDA dataset.
# Cannot find the drug D5W in FDA dataset.
# Cannot find the drug Amaryl in FDA dataset.
# Cannot find the drug Tamsulosin HCl in FDA dataset.
# Cannot find the drug Fluticasone-Salmeterol (100/50) in FDA dataset.
# Cannot find the drug Amiodarone HCl in FDA dataset.
# Cannot find the drug Soln in FDA dataset.
# Cannot find the drug NS in FDA dataset.
# Cannot find the drug D5W in FDA dataset.
# Cannot find the drug Enalapril Maleate in FDA dataset.
# Cannot find the drug Metoprolol XL in FDA dataset.
# Cannot find the drug Lidocaine in FDA dataset.
# Cannot find the drug Lidocaine in FDA dataset.
# Cannot find the drug Mexiletine HCl in FDA dataset.
# Cannot find the drug Amino Acids 4.25% W/ Dextrose 5% in FDA dataset.
# Cannot find the drug Lidocaine in FDA dataset.
# Cannot find the drug Terazosin HCl in FDA dataset.
# Cannot find the drug Atorvastatin in FDA dataset.
# Cannot find the drug Metoprolol Tartrate in FDA dataset.
# Cannot find the drug Albuterol 0.083% Neb Soln in FDA dataset.
# Cannot find the drug 0.9% Sodium Chloride in FDA dataset.
# Cannot find the drug Fentanyl Citrate in FDA dataset.
# Cannot find the drug 0.9% Sodium Chloride in FDA dataset.
# Cannot find the drug 5% Dextrose in FDA dataset.
# Cannot find the drug Chlorhexidine Gluconate 0.12% Oral Rinse in FDA dataset.
# Cannot find the drug Potassium Chloride (Powder) in FDA dataset.
# Cannot find the drug Hydrocortisone Na Succ. in FDA dataset.
# Cannot find the drug Heparin Flush PICC (100 units/ml) in FDA dataset.
# Cannot find the drug HydrALAZINE HCl in FDA dataset.
# Cannot find the drug Atorvastatin in FDA dataset.
# Cannot find the drug Brimonidine Tartrate 0.15% Ophth. in FDA dataset.
# Cannot find the drug Fentanyl Citrate in FDA dataset.
# Cannot find the drug 0.45% Sodium Chloride in FDA dataset.
# Cannot find the drug Dorzolamide 2%/Timolol 0.5% Ophth. in FDA dataset.
# Cannot find the drug Atorvastatin in FDA dataset.
# Cannot find the drug Albumin 5% (25 g) in FDA dataset.
# Cannot find the drug Dexmedetomidine HCl in FDA dataset.
# Cannot find the drug Ciprofloxacin HCl in FDA dataset.
# Cannot find the drug Sulfameth/Trimethoprim DS in FDA dataset.
# Cannot find the drug Sulfameth/Trimethoprim in FDA dataset.
# Cannot find the drug OxycoDONE (Immediate Release)  in FDA dataset.
# Cannot find the drug Zolpidem Tartrate in FDA dataset.
# Cannot find the drug Timolol Maleate 0.25% in FDA dataset.
# Cannot find the drug Amiodarone HCl in FDA dataset.
# Cannot find the drug Qvar in FDA dataset.
# Cannot find the drug Potassium Chl 20 mEq / 1000 mL D5NS in FDA dataset.
# Cannot find the drug Solution in FDA dataset.
# Cannot find the drug DiphenhydrAMINE HCl in FDA dataset.
# Cannot find the drug DiphenhydrAMINE HCl in FDA dataset.
# Cannot find the drug D5NS in FDA dataset.
# Cannot find the drug Pangestyme-EC in FDA dataset.
# Cannot find the drug Lidocaine 1%/Epinephrine 1:100000 in FDA dataset.
# Cannot find the drug Bupivacaine 0.25% in FDA dataset.
# Cannot find the drug Midazolam HCl in FDA dataset.
# Cannot find the drug Lidocaine 1% in FDA dataset.
# Cannot find the drug Thiamine HCl in FDA dataset.
# Cannot find the drug Sodium Chloride 3% (Hypertonic) in FDA dataset.
# Cannot find the drug Nephrocaps in FDA dataset.
# Cannot find the drug Carmustine in FDA dataset.
# Cannot find the drug Prevident Mint Gel 1.1% in FDA dataset.
# Cannot find the drug Ciprofloxacin HCl in FDA dataset.
# Cannot find the drug Hydrocortisone Na Succ. in FDA dataset.
# Cannot find the drug NS Epidural Bag (0.9% NaCl) in FDA dataset.
# Cannot find the drug Bupivacaine 0.5% in FDA dataset.
# Cannot find the drug Magnesium Citrate in FDA dataset.
# Cannot find the drug Atacand in FDA dataset.
# Cannot find the drug Procainamide HCl in FDA dataset.
# Cannot find the drug Aluminum Hydroxide Suspension in FDA dataset.
# Cannot find the drug Miconazole Powder 2% in FDA dataset.
# Cannot find the drug Vancomycin HCl in FDA dataset.
# Cannot find the drug Melphalan HCl in FDA dataset.
# Cannot find the drug Hydroxyzine HCl in FDA dataset.
# Cannot find the drug D5W in FDA dataset.
# Cannot find the drug Ambisome in FDA dataset.
# Cannot find the drug Eucerin in FDA dataset.
# Cannot find the drug Midazolam HCl in FDA dataset.
# Cannot find the drug Multivitamins in FDA dataset.
# Cannot find the drug Thiamine HCl in FDA dataset.
# Cannot find the drug Albumin 25% (12.5 g) in FDA dataset.
# Cannot find the drug Albumin, Human in FDA dataset.
# Cannot find the drug AMP in FDA dataset.
# Cannot find the drug *NF* Pentostatin in FDA dataset.
# Cannot find the drug Methylprednisolone Na Succ in FDA dataset.
# Cannot find the drug Pentamidine Inhalation in FDA dataset.
# Cannot find the drug Syringe (PCA) in FDA dataset.
# Cannot find the drug Lidocaine Jelly 2% (Urojet) in FDA dataset.
# Cannot find the drug Promethazine HCl in FDA dataset.
# Cannot find the drug Triamcinolone Acetonide 0.025% Cream in FDA dataset.
# Cannot find the drug Heparin Flush Hickman (100 units/ml) in FDA dataset.
# Cannot find the drug Hydrocortisone Na Succ. in FDA dataset.
# Cannot find the drug Ketoconazole 2%  in FDA dataset.
# Cannot find the drug Bicitra in FDA dataset.
# Cannot find the drug mege in FDA dataset.
# Cannot find the drug HydrOXYzine HCl in FDA dataset.
# Cannot find the drug Multivitamins in FDA dataset.
# Cannot find the drug Multivitamins in FDA dataset.
# Cannot find the drug Clonidine HCl in FDA dataset.
# Cannot find the drug Naloxone HCl in FDA dataset.
# Cannot find the drug Methadone HCl in FDA dataset.
# Cannot find the drug Methadone HCl in FDA dataset.
# Cannot find the drug Fluoxetine HCl in FDA dataset.
# Cannot find the drug Ethambutol HCl in FDA dataset.
# Cannot find the drug Aluminum-Magnesium Hydroxide in FDA dataset.
# Cannot find the drug traZODONE HCl in FDA dataset.
# Cannot find the drug NEO*IV*AMPicillin Sodium in FDA dataset.
# Cannot find the drug HydrALAZINE HCl in FDA dataset.
# Cannot find the drug Starter PN D10 in FDA dataset.
# Cannot find the drug NEO*IV*Caffeine Citrate in FDA dataset.
# Cannot find the drug NEO*PO*Caffeine Citrate in FDA dataset.
# Cannot find the drug NEO*PO*Ferrous Sulfate Elixir in FDA dataset.
# Cannot find the drug NEO*PO*Vitamin E Drops in FDA dataset.
# Cannot find the drug NEO*PO*MCT Oil in FDA dataset.
# Cannot find the drug Dexamethasone Ophthalmic Soln 0.1% in FDA dataset.
# Cannot find the drug NEO*NASAL*Phenylephrine 0.125% in FDA dataset.
# Cannot find the drug Prednisolone Acetate 0.12% Ophth. Susp. in FDA dataset.
# Cannot find the drug Sertraline HCl in FDA dataset.
# Cannot find the drug Nitroglycerin Oint. 2% in FDA dataset.
# Cannot find the drug Mupirocin Cream 2% in FDA dataset.
# Cannot find the drug Prismasate (B32 K2) in FDA dataset.
# Cannot find the drug D12.5W in FDA dataset.
# Cannot find the drug Potassium Chl 40 mEq / 1000 mL D5 1/2 NS in FDA dataset.
# Cannot find the drug Syringe (Neonatal) *SW* in FDA dataset.
# Cannot find the drug NEO*IV*Cefotaxime in FDA dataset.
# Cannot find the drug NEO*IV*Fentanyl in FDA dataset.
# Cannot find the drug Atorvastatin in FDA dataset.
# Cannot find the drug Mirapex in FDA dataset.
# Cannot find the drug Phenylephrine HCl in FDA dataset.
# Cannot find the drug 0.9% Sodium Chloride (Mini Bag Plus) in FDA dataset.
# Cannot find the drug Metoprolol Tartrate in FDA dataset.
# Cannot find the drug Metoprolol Tartrate in FDA dataset.
# Cannot find the drug Heparin Flush (10 units/ml) in FDA dataset.
# Cannot find the drug NEO*IM*Pneumococcal 7-Valent in FDA dataset.
# Cannot find the drug NEO*IM*Haemophilus B  Conj Vac in FDA dataset.
# Cannot find the drug NEO*PO*Chlorothiazide in FDA dataset.
# Cannot find the drug NEO*PO*MCT Oil in FDA dataset.
# Cannot find the drug NEO*PO*Vitamin E Drops in FDA dataset.
# Cannot find the drug Phenazopyridine HCl in FDA dataset.
# Cannot find the drug Timolol Maleate 0.5% in FDA dataset.
# Cannot find the drug Latanoprost 0.005% Ophth. Soln. in FDA dataset.
# Cannot find the drug Naloxone HCl in FDA dataset.
# Cannot find the drug Midazolam HCl in FDA dataset.
# Cannot find the drug Midodrine HCl in FDA dataset.
# Cannot find the drug Lidocaine 0.5%/Epinephrine in FDA dataset.
# Cannot find the drug NEO*IM*Palivizumab in FDA dataset.
# Cannot find the drug 1/2 NS in FDA dataset.
# Cannot find the drug NEO*IV*Hydrocortisone Sod Succinate in FDA dataset.
# Cannot find the drug Dopamine HCl in FDA dataset.
# Cannot find the drug NEO*Aquaphor in FDA dataset.
# Cannot find the drug NEO*IV*Caffeine Citrate in FDA dataset.
# Cannot find the drug Lidocaine 5% Patch in FDA dataset.
# Cannot find the drug Unasyn in FDA dataset.
# Cannot find the drug Fentanyl Citrate in FDA dataset.
# Cannot find the drug Lidocaine 1% in FDA dataset.
# Cannot find the drug D7.5W in FDA dataset.
# Cannot find the drug NEO*PO*Vitamin E Drops in FDA dataset.
# Cannot find the drug NEOMYCIN_POLYMYXIN_BACITRACIN in FDA dataset.
# Cannot find the drug NEO*PO*Caffeine Citrate in FDA dataset.
# Cannot find the drug NEO*PO*Mct Oil in FDA dataset.
# Cannot find the drug NEO*IM*DT  & Acellular Pertussis in FDA dataset.
# Cannot find the drug NEO*SC*Polio Vaccine (Inactive) in FDA dataset.
# Cannot find the drug NEO*PO*Acetaminophen Drops in FDA dataset.
# Cannot find the drug Starter PN D5 in FDA dataset.
# Cannot find the drug Sodium Bicarbonate 4.2% (2.4mEq) in FDA dataset.
# Cannot find the drug Syringe (Neonatal) *NS* in FDA dataset.
# Cannot find the drug NEO*IV*Indomethacin Sodium in FDA dataset.
# Cannot find the drug NEO*IV*Vancomycin in FDA dataset.
# Cannot find the drug Desitin in FDA dataset.
# Cannot find the drug NEO*IV*Cefazolin in FDA dataset.
# Cannot find the drug NEO*IM*DT  & Acellular Pertussis in FDA dataset.
# Cannot find the drug NEO*IM*Hepatitis B Vaccine in FDA dataset.
# Cannot find the drug Aluminum-Magnesium Hydroxide in FDA dataset.
# Cannot find the drug Midodrine HCl in FDA dataset.
# Cannot find the drug Rilutek in FDA dataset.
# Cannot find the drug sevelamer CARBONATE in FDA dataset.
# Cannot find the drug Nitroglycerin SL in FDA dataset.
# Cannot find the drug Heparin Flush (1000 units/mL) in FDA dataset.
# Cannot find the drug Sodium CITRATE 4% in FDA dataset.
# Cannot find the drug Cepacol (Menthol) in FDA dataset.
# Cannot find the drug NEO*PO*Poly-VI-solution in FDA dataset.
# Cannot find the drug Neo*Desitin Creamy in FDA dataset.
# Cannot find the drug Mannitol 20% in FDA dataset.
# Cannot find the drug Ciprofloxacin HCl in FDA dataset.
# Cannot find the drug Oxymetazoline HCl in FDA dataset.
# Cannot find the drug Pseudoephedrine HCl in FDA dataset.
# Cannot find the drug Vitamin B Complex w/C in FDA dataset.
# Cannot find the drug Nephrocaps in FDA dataset.
# Cannot find the drug Sterile Water in FDA dataset.
# Cannot find the drug Cinacalcet HCl in FDA dataset.
# Cannot find the drug Clonidine Patch 0.3 mg/24 hr in FDA dataset.
# Cannot find the drug Nitroglycerin Ointment  2% in FDA dataset.
# Cannot find the drug 5% Dextrose in FDA dataset.
# Cannot find the drug Tekturna in FDA dataset.
# Cannot find the drug Clonidine Patch 0.1 mg/24 hr in FDA dataset.
# Cannot find the drug sevelamer HYDROCHLORIDE in FDA dataset.
# Cannot find the drug Heparin Flush (5000 Units/mL) in FDA dataset.
# Cannot find the drug OxycodONE (Immediate Release)  in FDA dataset.
# Cannot find the drug Albumin 5% in FDA dataset.
# Cannot find the drug Piperacillin-Tazobactam Na in FDA dataset.
# Cannot find the drug ALBU in FDA dataset.
# Cannot find the drug Acetylcysteine 20% in FDA dataset.
# Cannot find the drug D5W in FDA dataset.
# Cannot find the drug Albumin 25% (12.5gm) in FDA dataset.
# Cannot find the drug Midazolam HCl in FDA dataset.
# Cannot find the drug 0.9% Sodium Chloride in FDA dataset.
# Cannot find the drug Albumin 5% (25g / 500mL) in FDA dataset.
# Cannot find the drug 5% Dextrose in FDA dataset.
# Cannot find the drug Labetalol HCl in FDA dataset.
# Cannot find the drug Miconazole Nitrate Vag Cream 2% in FDA dataset.
# Cannot find the drug NEO*IM*Palivizumab in FDA dataset.
# Cannot find the drug NEO*SC*Polio Vaccine (Inactive) in FDA dataset.
# Cannot find the drug Fat Emulsion 20% in FDA dataset.
# Cannot find the drug Terazosin HCl in FDA dataset.
# Cannot find the drug Vancomycin 25mg/mL Ophth Soln in FDA dataset.
# Cannot find the drug PrednisoLONE Acetate 1% Ophth. Susp. in FDA dataset.
# Cannot find the drug Oxycodone SR (OxyconTIN) in FDA dataset.
# Cannot find the drug Oxycodone SR (OxyconTIN) in FDA dataset.
# Cannot find the drug Oxycodone SR (OxyconTIN) in FDA dataset.
# Cannot find the drug viok in FDA dataset.
# Cannot find the drug Papain 2.5 % Solution in FDA dataset.
# Cannot find the drug Fluticasone-Salmeterol Diskus (250/50)  in FDA dataset.
# Cannot find the drug 5% Dextrose in FDA dataset.
# Cannot find the drug Methylprednisolone Na Succ. in FDA dataset.
# Cannot find the drug Methadone HCl in FDA dataset.
# Cannot find the drug Verapamil HCl in FDA dataset.
# Cannot find the drug Piperacillin-Tazobactam Na in FDA dataset.
# Cannot find the drug Lidocaine Viscous 2% in FDA dataset.
# Cannot find the drug Metoprolol Tartrate in FDA dataset.
# Cannot find the drug Foradil Aerolizer in FDA dataset.
# Cannot find the drug Acetylcysteine 20% in FDA dataset.
# Cannot find the drug Hydralazine HCl in FDA dataset.
# Cannot find the drug Clonidine Patch 0.2 mg/24 hr in FDA dataset.
# Cannot find the drug Methylprednisolone Na Succ. in FDA dataset.
# Cannot find the drug Bacitracin/Polymyxin B Sulfate Opht. Oint in FDA dataset.
# Cannot find the drug Potassium Chl 40 mEq / 1000 mL D5NS in FDA dataset.
# Cannot find the drug Albumin 5% (12.5g / 250mL) in FDA dataset.
# Cannot find the drug Piperacillin-Tazobactam Na in FDA dataset.
# Cannot find the drug Ciprofloxacin HCl in FDA dataset.
# Cannot find the drug Brimonidine Tartrate 0.15% Ophth. in FDA dataset.
# Cannot find the drug Ciprofloxacin 0.3% Ophth Soln in FDA dataset.
# Cannot find the drug Atropine Sulfate Ophth 1% in FDA dataset.
# Cannot find the drug ERY in FDA dataset.
# Cannot find the drug 1/4 NS in FDA dataset.
# Cannot find the drug Heparin Flush (10 units/ml) in FDA dataset.
# Cannot find the drug Albumin 25% (12.5g / 50mL) in FDA dataset.
# Cannot find the drug Diphenhydramine HCl in FDA dataset.
# Cannot find the drug Namenda in FDA dataset.
# Cannot find the drug Metoprolol XL in FDA dataset.
# Cannot find the drug Methylprednisolone Na Succ in FDA dataset.
# Cannot find the drug NEO*IV*Acyclovir in FDA dataset.
# Cannot find the drug Lidocaine Jelly 2% (Urojet) in FDA dataset.
# Cannot find the drug Miconazole Powder 2% in FDA dataset.
# Cannot find the drug Metoprolol Tartrate in FDA dataset.
# Cannot find the drug Magnesium Citrate in FDA dataset.
# Cannot find the drug Sulfameth/Trimethoprim Suspension in FDA dataset.
# Cannot find the drug Fluticasone-Salmeterol (250/50)  in FDA dataset.
# Cannot find the drug Cyclopentolate 1% in FDA dataset.
# Cannot find the drug Methadone HCl in FDA dataset.
# Cannot find the drug Erythromycin 0.5% Ophth Oint in FDA dataset.
# Cannot find the drug Prednisolone Acetate 1% Ophth. Susp. in FDA dataset.
# Cannot find the drug Levalbuterol HCl in FDA dataset.
# Cannot find the drug Metoprolol XL in FDA dataset.
# Cannot find the drug Nitroglycerin Oint. 2% in FDA dataset.
# Cannot find the drug Heparin Flush (100 units/ml) in FDA dataset.
# Cannot find the drug Dexmedetomidine HCl in FDA dataset.
# Cannot find the drug Atorvastatin in FDA dataset.
# Cannot find the drug *NF* Nitroglycerin Ointment in FDA dataset.
# Cannot find the drug Verapamil HCl in FDA dataset.
# Cannot find the drug Amitriptyline HCl in FDA dataset.
# Cannot find the drug Fentanyl Citrate in FDA dataset.
# Cannot find the drug Unasyn in FDA dataset.
# Cannot find the drug Methylprednisolone Na Succ in FDA dataset.
# Cannot find the drug D5W in FDA dataset.
# Cannot find the drug Iso-Osmotic Dextrose in FDA dataset.
# Cannot find the drug Dakins 1/2 Strength in FDA dataset.
# Cannot find the drug Debrox 6.5% in FDA dataset.
# Cannot find the drug Methylprednisolone Na Succ in FDA dataset.
# Cannot find the drug Vancomycin HCl in FDA dataset.
# Cannot find the drug Dextrose 50% in FDA dataset.
# Cannot find the drug Unasyn in FDA dataset.
# Cannot find the drug Bacitracin Ointment in FDA dataset.
# Cannot find the drug Clotrimazole Cream in FDA dataset.
# Cannot find the drug Lidocaine Jelly 2% (Urojet) in FDA dataset.
# Cannot find the drug Miconazole Powder 2% in FDA dataset.
# Cannot find the drug Betamethasone Dipro 0.05% Cream in FDA dataset.
# Cannot find the drug Verapamil HCl in FDA dataset.
# Cannot find the drug Loperamide HCl in FDA dataset.
# Cannot find the drug Cepacol (Menthol) in FDA dataset.
# Cannot find the drug Unasyn in FDA dataset.
# Cannot find the drug Sulfameth/Trimethoprim Suspension in FDA dataset.
# Cannot find the drug Phenylephrine HCl in FDA dataset.
# Cannot find the drug Chloral Hydrate (Syrup) in FDA dataset.
# Cannot find the drug Albumin 5% (12.5gm) in FDA dataset.
# Cannot find the drug Paroxetine HCl in FDA dataset.
# Cannot find the drug Mirapex in FDA dataset.
# Cannot find the drug Nitroglycerin SL in FDA dataset.
# Cannot find the drug Lidocaine Jelly 2% in FDA dataset.
# Cannot find the drug NEO*SC*Phytonadione in FDA dataset.
# Cannot find the drug Lepirudin in FDA dataset.
# Cannot find the drug Neo*Desitin Creamy in FDA dataset.
# Cannot find the drug Aluminum Hydroxide Suspension in FDA dataset.
# Cannot find the drug Betamethasone Dipro 0.05% Oint in FDA dataset.
# Cannot find the drug Zolpidem Tartrate in FDA dataset.
# Cannot find the drug Oxymetazoline HCl in FDA dataset.
# Cannot find the drug Nystatin Cream in FDA dataset.
# Cannot find the drug NS (Syringe) in FDA dataset.
# Cannot find the drug Lidocaine 0.5%/Epinephrine in FDA dataset.
# Cannot find the drug Nitroglycerin SL in FDA dataset.
# Cannot find the drug Acetaminophen w/Codeine in FDA dataset.
# Cannot find the drug Midazolam HCl in FDA dataset.
# Cannot find the drug 0.9% Sodium Chloride in FDA dataset.
# Cannot find the drug Sulfameth/Trimethoprim DS in FDA dataset.
# Cannot find the drug 5% Dextrose in FDA dataset.
# Cannot find the drug Sterile Water in FDA dataset.
# Cannot find the drug Promethazine HCl in FDA dataset.
# Cannot find the drug Citrate Dextrose 3% (ACD-A) CRRT in FDA dataset.
# Cannot find the drug Heparin Flush Port (10units/ml) in FDA dataset.
# Cannot find the drug Heparin Flush Midline (100 units/ml) in FDA dataset.
# Cannot find the drug Pioglitazone HCl in FDA dataset.
# Cannot find the drug Glipizide XL in FDA dataset.
# Cannot find the drug DiphenhydrAMINE HCl in FDA dataset.
# Cannot find the drug SW in FDA dataset.
# Cannot find the drug Dextrose 5% in FDA dataset.
# Cannot find the drug Acetylcysteine 20% in FDA dataset.
# Cannot find the drug Lidocaine 0.5% in FDA dataset.
# Cannot find the drug Hespan in FDA dataset.
# Cannot find the drug Cyclobenzaprine HCl in FDA dataset.
# Cannot find the drug Tizanidine HCl in FDA dataset.
# Cannot find the drug D5LR in FDA dataset.
# Cannot find the drug Psyllium Wafer in FDA dataset.
# Cannot find the drug Albumin 5% (12.5 g) in FDA dataset.
# Cannot find the drug Magnesium Citrate in FDA dataset.
# Cannot find the drug Acetaminophen w/Codeine Elixir in FDA dataset.
# Cannot find the drug Fluticasone-Salmeterol Diskus (100/50) in FDA dataset.
# Cannot find the drug Golytely in FDA dataset.
# Cannot find the drug Prednisolone Acetate 1% Ophth. Susp. in FDA dataset.
# Cannot find the drug Dorzolamide 2%/Timolol 0.5% Ophth. in FDA dataset.
# Cannot find the drug Methylprednisolone Na Succ in FDA dataset.
# Cannot find the drug Golytely in FDA dataset.
# Cannot find the drug Hydroxyzine HCl in FDA dataset.
# Cannot find the drug Ciprofloxacin HCl in FDA dataset.
# Cannot find the drug zinc oxide in FDA dataset.
# Cannot find the drug Potassium Chl 20 mEq / 1000 mL D5LR in FDA dataset.
# Cannot find the drug Multivitamins in FDA dataset.
# Cannot find the drug Piperacillin-Tazobactam Na in FDA dataset.
# Cannot find the drug Acetami in FDA dataset.
# Cannot find the drug Paroxetine HCl in FDA dataset.
# Cannot find the drug Lidocaine Jelly 2% in FDA dataset.
# Cannot find the drug Propranolol HCl in FDA dataset.
# Cannot find the drug Readi-Cat 2 (Barium Sulfate 2% Suspension) in FDA dataset.
# Cannot find the drug Heparin (CRRT Machine Priming) in FDA dataset.
# Cannot find the drug Hydrocortisone Na Succ. in FDA dataset.
# Cannot find the drug Acetami in FDA dataset.
# Cannot find the drug Sulfameth/Trimethoprim SS in FDA dataset.
# Cannot find the drug Pulmicort in FDA dataset.
# Cannot find the drug Heparin Flush PICC (100 units/ml) in FDA dataset.
# Cannot find the drug Albumin 25% (12.5gm) in FDA dataset.
# Cannot find the drug GlipiZIDE XL in FDA dataset.
# Cannot find the drug Lidocaine 5% Ointment in FDA dataset.
# Cannot find the drug Magnesium Oxide in FDA dataset.
# Cannot find the drug Lidocaine 1% in FDA dataset.
# Cannot find the drug Sulfameth/Trimethoprim in FDA dataset.
# Cannot find the drug Fentanyl Citrate in FDA dataset.
# Cannot find the drug Methylprednisolone Na Succ. in FDA dataset.
# Cannot find the drug Sodium Citrate/Citric Acid in FDA dataset.
# Cannot find the drug Metoprolol Tartrate in FDA dataset.
# Cannot find the drug Norepinephrine Bitartrate in FDA dataset.
# Cannot find the drug Midazolam HCl in FDA dataset.
# Cannot find the drug OxycoDONE (Immediate Release)  in FDA dataset.
# Cannot find the drug Escitalopram Oxalate in FDA dataset.
# Cannot find the drug Multivitamins in FDA dataset.
# Cannot find the drug NS in FDA dataset.
# Cannot find the drug Unasyn in FDA dataset.
# Cannot find the drug NS in FDA dataset.
# Cannot find the drug Erythromycin Lactobionate in FDA dataset.
# Cannot find the drug Fluoxetine HCl in FDA dataset.
# Cannot find the drug Trisodium Citrate 0.4% Replacement Soln in FDA dataset.
# Cannot find the drug Lidocaine-Prilocaine in FDA dataset.
# Cannot find the drug Procainamide HCl in FDA dataset.
# Cannot find the drug Ethambutol HCl in FDA dataset.
# Cannot find the drug Ethambutol HCl in FDA dataset.
# Cannot find the drug Caphosol in FDA dataset.
# Cannot find the drug Gelclair in FDA dataset.
# Cannot find the drug Lidocaine in FDA dataset.
# Cannot find the drug Acetaminophen w/Codeine in FDA dataset.
# Cannot find the drug Lidocaine 1% in FDA dataset.
# Cannot find the drug Amprenavir in FDA dataset.
# Cannot find the drug MoviPrep in FDA dataset.
# Cannot find the drug Accolate in FDA dataset.
# Cannot find the drug Sotalol HCl in FDA dataset.
# Cannot find the drug Methylprednisolone Na Succ in FDA dataset.
# Cannot find the drug Pyridoxine HCl in FDA dataset.
# Cannot find the drug Heparin Flush (10 units/ml) in FDA dataset.
# Cannot find the drug Potassium Chl 40 mEq / 1000 mL NS in FDA dataset.
# Cannot find the drug Tobramycin Inhalation Soln in FDA dataset.
# Cannot find the drug Nicardipine HCl IV in FDA dataset.
# Cannot find the drug Silver Sulfadiazine 1% Cream in FDA dataset.
# Cannot find the drug Albumin 5% in FDA dataset.
# Cannot find the drug Dorzolamide 2%/Timolol 0.5% Ophth. in FDA dataset.
# Cannot find the drug Multivitamins W/minerals in FDA dataset.
# Cannot find the drug Dakins 1/4 Strength in FDA dataset.
# Cannot find the drug Oxycodone SR (OxyconTIN) in FDA dataset.
# Cannot find the drug Oxycodone SR (OxyconTIN) in FDA dataset.
# Cannot find the drug GlipiZIDE XL in FDA dataset.
# Cannot find the drug Travatan in FDA dataset.
# Cannot find the drug 5% Dextrose in FDA dataset.
# Cannot find the drug Viagra in FDA dataset.
# Cannot find the drug Magnesium Oxide in FDA dataset.
# Cannot find the drug Chlorpromazine HCl in FDA dataset.
# Cannot find the drug Lidocaine Jelly 2% in FDA dataset.
# Cannot find the drug Nystatin Ointment in FDA dataset.
# Cannot find the drug Dobutamine HCl in FDA dataset.
# Cannot find the drug Tucks Hemorrhoidal Oint 1% in FDA dataset.
# Cannot find the drug CycloSPORINE (Sandimmune) in FDA dataset.
# Cannot find the drug CycloSPORINE (Sandimmune) in FDA dataset.
# Cannot find the drug Mupirocin Cream 2% in FDA dataset.
# Cannot find the drug Moexipril HCl in FDA dataset.
# Cannot find the drug Zolpidem Tartrate in FDA dataset.
# Cannot find the drug Metoprolol XL (Toprol XL) in FDA dataset.
# Cannot find the drug Albumin 25% (12.5gm) in FDA dataset.
# Cannot find the drug 1/2 NS in FDA dataset.
# Cannot find the drug Rosiglitazone Maleate in FDA dataset.
# Cannot find the drug Syringe (Intrapleural) in FDA dataset.
# Cannot find the drug Miralax in FDA dataset.
# Cannot find the drug 5% Dextrose in FDA dataset.
# Cannot find the drug Lithium Carbonate in FDA dataset.
# Cannot find the drug Nicotine Polacrilex in FDA dataset.
# Cannot find the drug Silver Sulfadiazine 1% Cream in FDA dataset.
# Cannot find the drug Sodium Citrate 4% in FDA dataset.
# Cannot find the drug Acetylcysteine 20% in FDA dataset.
# Cannot find the drug Oxymetazoline HCl in FDA dataset.
# Cannot find the drug Epoprostenol Na in FDA dataset.
# Cannot find the drug Amitriptyline HCl in FDA dataset.
# Cannot find the drug Patanol in FDA dataset.
# Cannot find the drug Vivelle-Dot in FDA dataset.
# Cannot find the drug Salagen in FDA dataset.
# Cannot find the drug NEO*SC*Phytonadione in FDA dataset.
# Cannot find the drug Erythromycin 0.5% Ophth Oint in FDA dataset.
# Cannot find the drug Heparin Flush CVL  (100 units/ml) in FDA dataset.
# Cannot find the drug Naloxone HCl in FDA dataset.
# Cannot find the drug HydrOXYzine HCl in FDA dataset.
# Cannot find the drug Hydrocortisone Cream 1% in FDA dataset.
# Cannot find the drug Propranolol HCl in FDA dataset.
# Cannot find the drug Clobetasol Propionate 0.05% Ointment in FDA dataset.
# Cannot find the drug Ethanol 70% Catheter DWELL in FDA dataset.
# Cannot find the drug Prazosin HCl in FDA dataset.
# Cannot find the drug Prazosin HCl in FDA dataset.
# Cannot find the drug Desonide 0.05% Cream in FDA dataset.
# Cannot find the drug Triamcinolone Acetonide 0.1% Ointment in FDA dataset.
# Cannot find the drug Hydrocortisone Cream 2.5% in FDA dataset.
# Cannot find the drug Albumin 25% (12.5g / 50mL) in FDA dataset.
# Cannot find the drug Tetracycline HCl in FDA dataset.
# Cannot find the drug Bismuth Subsalicylate Chewable in FDA dataset.
# Cannot find the drug Amiodarone HCl in FDA dataset.
# Cannot find the drug Phenylephrine HCl in FDA dataset.
# Cannot find the drug Methadone Hcl in FDA dataset.
# Cannot find the drug Methadone PCA in FDA dataset.
# Cannot find the drug Amitriptyline HCl in FDA dataset.
# Cannot find the drug NS in FDA dataset.
# Cannot find the drug Miconazole 2% Cream in FDA dataset.
# Cannot find the drug Lidocaine 1%/Epinephrine 1:100000 in FDA dataset.
# Cannot find the drug Vioxx in FDA dataset.
# Cannot find the drug Restasis in FDA dataset.
# Cannot find the drug Systane in FDA dataset.
# Cannot find the drug Fluocinolone Acetonide 0.025% Cream in FDA dataset.
# Cannot find the drug Bacitracin Ointment in FDA dataset.
# Cannot find the drug GlipiZIDE XL in FDA dataset.
# Cannot find the drug Hydrocortisone Cream 0.5% in FDA dataset.
# Cannot find the drug Piperacillin-Tazobactam Na in FDA dataset.
# Cannot find the drug Kaopectate/Benadryl/Lido Visc. in FDA dataset.
# Cannot find the drug Epinephrine Inhalation in FDA dataset.
# Cannot find the drug Metoprolol XL in FDA dataset.
# Cannot find the drug Imitrex in FDA dataset.
# Cannot find the drug Tylenol w/Codeine Elixir in FDA dataset.
# Cannot find the drug Acetaminophen w/Codeine in FDA dataset.
# Cannot find the drug Hydrocortisone Acetate Ointment 1% in FDA dataset.
# Cannot find the drug Debrox 6.5% in FDA dataset.
# Cannot find the drug Leucovorin Calcium in FDA dataset.
# Cannot find the drug Fentanyl Citrate in FDA dataset.
# Cannot find the drug Kaletra in FDA dataset.
# Cannot find the drug Methylene Blue 1% in FDA dataset.
# Cannot find the drug Calcium Citrate in FDA dataset.
# Cannot find the drug Lidocaine 1% in FDA dataset.
# Cannot find the drug Intralipid 20% in FDA dataset.
# Cannot find the drug Intralipid 20% in FDA dataset.
# Cannot find the drug Lidocaine 1% in FDA dataset.
# Cannot find the drug Sodium Chloride 23.4% in FDA dataset.
# Cannot find the drug Loperamide Hcl in FDA dataset.
# Cannot find the drug Phenazopyridine HCl in FDA dataset.
# Cannot find the drug Acetaminophen w/Codeine Elixir in FDA dataset.
# Cannot find the drug Avapro in FDA dataset.
# Cannot find the drug Hydrocortisone Cream 1% in FDA dataset.
# Cannot find the drug pilocarpine HCl in FDA dataset.
# Cannot find the drug TRISODIUM CITRATE 4% REPLACEMENT FLUID (Dialysis) in FDA dataset.
# Cannot find the drug Ropinirole HCl in FDA dataset.
# Cannot find the drug Hydrocerin in FDA dataset.
# Cannot find the drug Leucovorin Calcium in FDA dataset.
# Cannot find the drug Tobramycin Inhalation Soln in FDA dataset.
# Cannot find the drug NEO*IV*Clindamycin in FDA dataset.
# Cannot find the drug *NF* Mycophenolate Sodium in FDA dataset.
# Cannot find the drug Myfortic in FDA dataset.
# Cannot find the drug Muromonab-CD3 in FDA dataset.
# Cannot find the drug Multivitamins in FDA dataset.
# Cannot find the drug Critic-Aid Skin Paste in FDA dataset.
# Cannot find the drug Rosiglitazone Maleate in FDA dataset.
# Cannot find the drug NS in FDA dataset.
# Cannot find the drug Sodium Chloride 0.9% in FDA dataset.
# Cannot find the drug Amiloride HCl in FDA dataset.
# Cannot find the drug Syringe (Neonatal) *D10W* in FDA dataset.
# Cannot find the drug NEO*IV*Oxacillin in FDA dataset.
# Cannot find the drug Heparin Flush Port (10units/ml) in FDA dataset.
# Cannot find the drug Clobetasol Propionate 0.05% Cream in FDA dataset.
# Cannot find the drug Capsaicin 0.025% in FDA dataset.
# Cannot find the drug Lidocaine 1% in FDA dataset.
# Cannot find the drug Tucks Hemorrhoidal Oint 1% in FDA dataset.
# Cannot find the drug Xopenex in FDA dataset.
# Cannot find the drug Mupirocin Nasal Ointment 2% in FDA dataset.
# Cannot find the drug NEO*PO*Ranitidine in FDA dataset.
# Cannot find the drug NEO*PO*Metoclopramide in FDA dataset.
# Cannot find the drug Albumin 5% (25g / 500mL) in FDA dataset.
# Cannot find the drug Travasol 4.25% W/ Dextrose 5% in FDA dataset.
# Cannot find the drug Chlorpromazine HCl in FDA dataset.
# Cannot find the drug Methylprednisolone Na Succ in FDA dataset.
# Cannot find the drug Dopamine HCl in FDA dataset.
# Cannot find the drug Trimethobenzamide HCl in FDA dataset.
# Cannot find the drug Fentanyl Citrate in FDA dataset.
# Cannot find the drug Albumin 25% (12.5gm) in FDA dataset.
# Cannot find the drug NEO*IV*Dexamethasone in FDA dataset.
# Cannot find the drug NEO*PO*Opium Tincture (Dilute) in FDA dataset.
# Cannot find the drug Intralipid/Liposyn III (Plastic) in FDA dataset.
# Cannot find the drug NEO*IV*Morphine Sulfate in FDA dataset.
# Cannot find the drug NEO*IV*Fat Emulsion in FDA dataset.
# Cannot find the drug NEO*IV*Hydrocortisone (1mg/mL) in FDA dataset.
# Cannot find the drug NEO*PO*Dexamethasone in FDA dataset.
# Cannot find the drug NEO*PO*Spironolactone in FDA dataset.
# Cannot find the drug Morphine (PF) in FDA dataset.
# Cannot find the drug NEO*IV*Insulin (Dilute) in FDA dataset.
# Cannot find the drug Sterile Water in FDA dataset.
# Cannot find the drug Paroxetine HCl in FDA dataset.
# Cannot find the drug Miralax in FDA dataset.
# Cannot find the drug Mannitol 20 % in FDA dataset.
# Cannot find the drug NEO*IV*PHENObarbital in FDA dataset.
# Cannot find the drug Vitamin E in FDA dataset.
# Cannot find the drug Meclizine HCl in FDA dataset.
# Cannot find the drug Methylene Blue 1% in FDA dataset.
# Cannot find the drug Syringe (0.9% Sodium Chloride) in FDA dataset.
# Cannot find the drug Sulfameth/Trimethoprim  in FDA dataset.
# Cannot find the drug Lexapro in FDA dataset.
# Cannot find the drug Bupivacaine 0.5% in FDA dataset.
# Cannot find the drug Albumin 5% (12.5g) in FDA dataset.
# Cannot find the drug Albumin 5% ( in FDA dataset.
# Cannot find the drug Syringe (Intrathecal) in FDA dataset.
# Cannot find the drug NEO*PO*SODium Chloride in FDA dataset.
# Cannot find the drug Atropine Sulfate 1% Ophth Ointment in FDA dataset.
# Cannot find the drug *NF* Dornase Alfa Inh. Soln. in FDA dataset.
# Cannot find the drug Pyridoxine HCl in FDA dataset.
# Cannot find the drug Hydrocortisone Na Succinate in FDA dataset.
# Cannot find the drug Morphine PCA in FDA dataset.
# Cannot find the drug Leucovorin Calcium in FDA dataset.
# Cannot find the drug Leucovorin Calcium in FDA dataset.
# Cannot find the drug Critic-Aid Skin Paste in FDA dataset.
# Cannot find the drug NEO*IM*Dt & Acellular Pertussis in FDA dataset.
# Cannot find the drug NEO*IM*Haemophilus B Conjugate in FDA dataset.
# Cannot find the drug Sulfameth/Trimethoprim in FDA dataset.
# Cannot find the drug SURGIFOAM in FDA dataset.
# Cannot find the drug Surgicel in FDA dataset.
# Cannot find the drug Lidocaine 0.5% in FDA dataset.
# Cannot find the drug Fluoxetine HCl in FDA dataset.
# Cannot find the drug Hydrocortisone Cream 0.5% in FDA dataset.
# Cannot find the drug Bupropion HCl in FDA dataset.
# Cannot find the drug HydrOXYzine HCl in FDA dataset.
# Cannot find the drug Calcipotriene 0.005% Cream in FDA dataset.
# Cannot find the drug Amino Acids 5%-Dextrose 15% in FDA dataset.
# Cannot find the drug *NF* Ertapenem Sodium in FDA dataset.
# Cannot find the drug Alternagel-Benadryl-Lidocaine Visc. in FDA dataset.
# Cannot find the drug Heparin Flush CVL  (100 units/ml) in FDA dataset.
# Cannot find the drug Benzocaine 20% Spray in FDA dataset.
# Cannot find the drug Methylphenidate HCl in FDA dataset.
# Cannot find the drug Fluvoxamine Maleate in FDA dataset.
# Cannot find the drug Papain-Urea Ointment in FDA dataset.
# Cannot find the drug Ranitidine HCl in FDA dataset.
# Cannot find the drug Evista in FDA dataset.
# Cannot find the drug Aluminum Hydroxide in FDA dataset.
# Cannot find the drug Morphine Sulfate (Immediate Release) in FDA dataset.
# Cannot find the drug Meperidine HCl in FDA dataset.
# Cannot find the drug Provigil in FDA dataset.
# Cannot find the drug Ticlopidine HCl in FDA dataset.
# Cannot find the drug Comtan in FDA dataset.
# Cannot find the drug Silver Sulfadiazine 1% Cream in FDA dataset.
# Cannot find the drug Amaryl in FDA dataset.
# Cannot find the drug D15W in FDA dataset.
# Cannot find the drug Metformin HCl in FDA dataset.
# Cannot find the drug Ondansetron HCl in FDA dataset.
# Cannot find the drug *NF* Salmeterol-Fluticasone in FDA dataset.
# Cannot find the drug Clarinex in FDA dataset.
# Cannot find the drug Metoprolol XL (Toprol XL) in FDA dataset.
# Cannot find the drug Lotrel in FDA dataset.
# Cannot find the drug Sulfamylon in FDA dataset.
# Cannot find the drug Lithium Carbonate in FDA dataset.
# Cannot find the drug Tricor in FDA dataset.
# Cannot find the drug Fentanyl PCA in FDA dataset.
# Cannot find the drug *NF* Gelclair in FDA dataset.
# Cannot find the drug Bacitracin Ointment in FDA dataset.
# Cannot find the drug Cyclopentolate 1% in FDA dataset.
# Cannot find the drug Pseudoephedrine HCl in FDA dataset.
# Cannot find the drug Atropine Sulfate Ophth 1% in FDA dataset.
# Cannot find the drug Flurbiprofen 0.03% in FDA dataset.
# Cannot find the drug Verapamil HCl in FDA dataset.
# Cannot find the drug Nicotine Lozenge in FDA dataset.
# Cannot find the drug Anzemet in FDA dataset.
# Cannot find the drug Betaxolol Hcl  0.25% in FDA dataset.
# Cannot find the drug Soma in FDA dataset.
# Cannot find the drug Glyburide/Metformin (5mg-500mg) in FDA dataset.
# Cannot find the drug Acyclovir Ointment 5% in FDA dataset.
# Cannot find the drug Caffeine-Sodium Benzoate in FDA dataset.
# Cannot find the drug Foradil Aerolizer in FDA dataset.
# Cannot find the drug Metoprolol XL (Toprol XL) in FDA dataset.
# Cannot find the drug Coenzyme Q10 in FDA dataset.
# Cannot find the drug Ciprofloxacin HCl in FDA dataset.
# Cannot find the drug NEO*IV*Hydralazine in FDA dataset.
# Cannot find the drug NEO*PO*Captopril in FDA dataset.
# Cannot find the drug Phenylephrine 2.5 % Ophth Soln in FDA dataset.
# Cannot find the drug Tropicamide 1 % in FDA dataset.
# Cannot find the drug D25W in FDA dataset.
# Cannot find the drug Lidocaine 2% in FDA dataset.
# Cannot find the drug Collagenase Ointment in FDA dataset.
# Cannot find the drug Fluvoxamine Maleate in FDA dataset.
# Cannot find the drug Becaplermin Gel 0.01% in FDA dataset.
# Cannot find the drug Clotrimazole Cream in FDA dataset.
# Cannot find the drug Potassium Chl 40 mEq / 1000 mL D5W in FDA dataset.
# Cannot find the drug Glyburide/Metformin (2.5mg-500mg) in FDA dataset.
# Cannot find the drug Rosiglitazone Maleate in FDA dataset.
# Cannot find the drug Alteplase 1mg/1mL ( Clearance ie. Temp TLCL ) in FDA dataset.
# Cannot find the drug NEO*IV*Phenobarbital in FDA dataset.
# Cannot find the drug Propranolol HCl in FDA dataset.
# Cannot find the drug Collagenase Ointment in FDA dataset.
# Cannot find the drug D5 1/4NS in FDA dataset.
# Cannot find the drug Hydrocortisone Acetate Ointment 1% in FDA dataset.
# Cannot find the drug Triamcinolone Acetonide 0.1% Cream in FDA dataset.
# Cannot find the drug Timolol Maleate 0.5% in FDA dataset.
# Cannot find the drug Pulmicort in FDA dataset.
# Cannot find the drug GlipiZIDE XL in FDA dataset.
# Cannot find the drug Pioglitazone HCl in FDA dataset.
# Cannot find the drug Clindamycin HCl in FDA dataset.
# Cannot find the drug Aspir in FDA dataset.
# Cannot find the drug Aspiri in FDA dataset.
# Cannot find the drug *NF* Tacrolimus Suspension in FDA dataset.
# Cannot find the drug Remifentanil HCl in FDA dataset.
# Cannot find the drug Benicar in FDA dataset.
# Cannot find the drug Acebutolol HCl in FDA dataset.
# Cannot find the drug Tobramycin 0.3% Ophth Soln in FDA dataset.
# Cannot find the drug Lumigan in FDA dataset.
# Cannot find the drug NEO*PO*Potassium Chloride in FDA dataset.
# Cannot find the drug CycloSPORINE (Sandimmune) in FDA dataset.
# Cannot find the drug Gemcitabine HCl in FDA dataset.
# Cannot find the drug Heparin Flush Port (10 units/mL) in FDA dataset.
# Cannot find the drug Roxanol in FDA dataset.
# Cannot find the drug Atacand in FDA dataset.
# Cannot find the drug Triamcinolone 0.1% Ointment in FDA dataset.
# Cannot find the drug Fluoxetine HCl in FDA dataset.
# Cannot find the drug CycloSPORINE (Sandimmune) in FDA dataset.
# Cannot find the drug mega in FDA dataset.
# Cannot find the drug Quinupristin/Dalfopristin in FDA dataset.
# Cannot find the drug Paroxetine HCl in FDA dataset.
# Cannot find the drug Pilocarpine 0.5% in FDA dataset.
# Cannot find the drug Levobunolol Hcl 0.25% in FDA dataset.
# Cannot find the drug Skelaxin in FDA dataset.
# Cannot find the drug Acebutolol HCl in FDA dataset.
# Cannot find the drug Methylene Blue 1% in FDA dataset.
# Cannot find the drug Lidocaine in FDA dataset.
# Cannot find the drug Triamcinolone Acetonide 0.1% Cream in FDA dataset.
# Cannot find the drug Methylphenidate HCl in FDA dataset.
# Cannot find the drug Proparacaine HCl 0.5% Opth. in FDA dataset.
# Cannot find the drug Glipizide XL in FDA dataset.
# Cannot find the drug Intralipid/Liposyn III (Glass) in FDA dataset.
# Cannot find the drug Nexium in FDA dataset.
# Cannot find the drug *NF* Capecitabine in FDA dataset.
# Cannot find the drug Thiamine HCl in FDA dataset.
# Cannot find the drug Neo*PO*Omeprazole in FDA dataset.
# Cannot find the drug Chlordiazepoxide HCl in FDA dataset.
# Cannot find the drug Povidone Iodine 1/8 Strength in FDA dataset.
# Cannot find the drug NS in FDA dataset.
# Cannot find the drug D17.5W in FDA dataset.
# Cannot find the drug Benicar in FDA dataset.
# Cannot find the drug Abilify in FDA dataset.
# Cannot find the drug dival in FDA dataset.
# Cannot find the drug Aquaphor Ointment in FDA dataset.
# Cannot find the drug Tizanidine HCl in FDA dataset.
# Cannot find the drug Citric Acid/Sodium Citrate in FDA dataset.
# Cannot find the drug Orabase w/ Benzocaine Paste in FDA dataset.
# Cannot find the drug Metoclopramide HCl in FDA dataset.
# Cannot find the drug KCl in FDA dataset.
# Cannot find the drug *NF* Basiliximab in FDA dataset.
# Cannot find the drug Pioglitazone HCl in FDA dataset.
# Cannot find the drug Methadone HCl in FDA dataset.
# Cannot find the drug Acyclovir Ointment 5% in FDA dataset.
# Cannot find the drug Humalog in FDA dataset.
# Cannot find the drug Dopamine Hcl in FDA dataset.
# Cannot find the drug Imipramine HCl in FDA dataset.
# Cannot find the drug Propranolol HCl in FDA dataset.
# Cannot find the drug Rosuvastatin Calcium in FDA dataset.
# Cannot find the drug Ketamine Study Drug (*IND*) in FDA dataset.
# Cannot find the drug Sildenafil Citrate in FDA dataset.
# Cannot find the drug Paroxetine HCl in FDA dataset.
# Cannot find the drug 5% Dextrose (EXCEL BAG) in FDA dataset.
# Cannot find the drug Terbinafine 1% Cream in FDA dataset.
# Cannot find the drug Verapamil HCl in FDA dataset.
# Cannot find the drug valp in FDA dataset.
# Cannot find the drug Lidocaine 0.5% in FDA dataset.
# Cannot find the drug Arimidex in FDA dataset.
# Cannot find the drug Miconazole 2% Cream in FDA dataset.
# Cannot find the drug Pilocarpine 1% in FDA dataset.
# Cannot find the drug Terazosin HCl in FDA dataset.
# Cannot find the drug Triamcinolone Acetonide 0.1% Ointment in FDA dataset.
# Cannot find the drug Cipro in FDA dataset.
# Cannot find the drug Vitamin B Complex w/C in FDA dataset.
# Cannot find the drug *IND* Pexelizumab/Placebo in FDA dataset.
# Cannot find the drug Meperidine PF in FDA dataset.
# Cannot find the drug Fluocinonide 0.05% Ointment in FDA dataset.
# Cannot find the drug Betaxolol Hcl  0.25% in FDA dataset.
# Cannot find the drug Estradiol in FDA dataset.
# Cannot find the drug Nicotine Polacrilex in FDA dataset.
# Cannot find the drug Dextran 40 10% in FDA dataset.
# Cannot find the drug NEO*IM*Palivizumab in FDA dataset.
# Cannot find the drug Doxepin HCl in FDA dataset.
# Cannot find the drug Anusol Ointment 1% in FDA dataset.
# Cannot find the drug Hydrocortisone (Rectal) 2.5% Cream in FDA dataset.
# Cannot find the drug Paroxetine HCl in FDA dataset.
# Cannot find the drug Methylphenidate HCl in FDA dataset.
# Cannot find the drug Capt in FDA dataset.
# Cannot find the drug Terbinafine 1% Cream in FDA dataset.
# Cannot find the drug Mevacor in FDA dataset.
# Cannot find the drug Bupivacaine 0.50% in FDA dataset.
# Cannot find the drug Thioridazine HCl in FDA dataset.
# Cannot find the drug Tricor in FDA dataset.
# Cannot find the drug Bengay in FDA dataset.
# Cannot find the drug Fluocinonide 0.05% Ointment in FDA dataset.
# Cannot find the drug Sodium Chloride 3% (Hypertonic) in FDA dataset.
# Cannot find the drug Mirapex in FDA dataset.
# Cannot find the drug Sodium Bicarbonate 4.2% (2.4meq) in FDA dataset.
# Cannot find the drug Ropinirole HCl in FDA dataset.
# Cannot find the drug Meclizine HCl in FDA dataset.
# Cannot find the drug NEO*PO*Sodium Chloride in FDA dataset.
# Cannot find the drug *NF* Pediatric Vitamins ADC in FDA dataset.
# Cannot find the drug Naloxone HCl in FDA dataset.
# Cannot find the drug Albumin 5% (25g / 500mL) in FDA dataset.
# Cannot find the drug Zofran in FDA dataset.
# Cannot find the drug SKELAXIN in FDA dataset.
# Cannot find the drug Lidocaine Jelly 2% in FDA dataset.
# Cannot find the drug Oxymetazoline HCl in FDA dataset.
# Cannot find the drug Lidocaine 5% Ointment in FDA dataset.
# Cannot find the drug Chlorpheniramine Maleate in FDA dataset.
# Cannot find the drug Lidocaine 1% in FDA dataset.
# Cannot find the drug Naphazoline 0.1% Ophth in FDA dataset.
# Cannot find the drug Triamcinolone 0.1% Cream in FDA dataset.
# Cannot find the drug Bupropion HCl in FDA dataset.
# Cannot find the drug Timolol Maleate 0.5% in FDA dataset.
# ...
# Cannot find the drug Sulfameth/Trimethoprim Suspension in FDA dataset.
# Cannot find the drug Mitomycin in FDA dataset.
# Cannot find the drug Methadone HCl in FDA dataset.
# Cannot find the drug Atorvastatin in FDA dataset.
# Cannot find the drug Fluorometholone 0.1% Ophth Susp. in FDA dataset.
# Cannot find the drug Actiq in FDA dataset.
# Cannot find the drug Pancrelipase 4500 in FDA dataset.
# Cannot find the drug Mirapex in FDA dataset.
# Cannot find the drug Oxycodone SR (OxyconTIN) in FDA dataset.
# Cannot find the drug bismu in FDA dataset.
# Cannot find the drug Agrylin in FDA dataset.
# Cannot find the drug Hydromorphone PCA in FDA dataset.
# Cannot find the drug Chlorpromazine HCl in FDA dataset.
# Cannot find the drug Povidone Iodine 10% Ointment in FDA dataset.
# Cannot find the drug Hydroxyzine HCl in FDA dataset.
# Cannot find the drug Zocor in FDA dataset.
# Cannot find the drug Lithium Carbonate in FDA dataset.
# Cannot find the drug Lidocaine  in FDA dataset.
# Cannot find the drug triazol in FDA dataset.
# Cannot find the drug TRAVATAN Z in FDA dataset.
# Cannot find the drug diltia in FDA dataset.
# Cannot find the drug LESCOL in FDA dataset.
# Cannot find the drug Vivelle in FDA dataset.
# Cannot find the drug *NF* Risedronate Sodium in FDA dataset.
# Cannot find the drug hyo in FDA dataset.
# Cannot find the drug *NF* Temozolomide in FDA dataset.
# Cannot find the drug Percocet in FDA dataset.
# Cannot find the drug Percocet in FDA dataset.
# Cannot find the drug D5W in FDA dataset.
# Cannot find the drug Pletal in FDA dataset.
# Cannot find the drug *NF* Digoxin (Lanoxicaps) in FDA dataset.
# Cannot find the drug Belatacept Study Drug (*IND*) in FDA dataset.
# Cannot find the drug PreserVision in FDA dataset.
# Cannot find the drug Lanoxicaps in FDA dataset.
# Cannot find the drug Advicor in FDA dataset.
# Cannot find the drug Lotrel in FDA dataset.
# Cannot find the drug Belladonna & Opium in FDA dataset.
# Cannot find the drug Daunorubicin HCl in FDA dataset.
# Cannot find the drug Bupivacaine 0.75% in FDA dataset.
# Cannot find the drug Forteo in FDA dataset.
# Cannot find the drug Kaolin/Pectin in FDA dataset.
# Cannot find the drug Lidocaine 1% in FDA dataset.
# Cannot find the drug Alavert in FDA dataset.
# Cannot find the drug Enbrel in FDA dataset.
# Cannot find the drug Rhinocort Aqua in FDA dataset.
# Cannot find the drug Norethindrone-Estradiol in FDA dataset.
# Cannot find the drug Nicotine Lozenge in FDA dataset.
# Cannot find the drug AndroGel in FDA dataset.
# Cannot find the drug Estraderm in FDA dataset.
# Cannot find the drug Fentanyl Citrate in FDA dataset.
# Cannot find the drug Phenytoi in FDA dataset.
# Cannot find the drug CONCERTA in FDA dataset.
# Cannot find the drug hyosc in FDA dataset.
# Cannot find the drug Chantix in FDA dataset.
# Cannot find the drug Lidocaine Ointment 5% in FDA dataset.
# Cannot find the drug Norflex in FDA dataset.
# Cannot find the drug Promethazine HCl in FDA dataset.
# Cannot find the drug Endur-Acin in FDA dataset.
# Cannot find the drug Osmoglyn in FDA dataset.
# Cannot find the drug *NF* Paroxetine CR in FDA dataset.
# Cannot find the drug Erythromycin Ethylsuccinate in FDA dataset.
# Cannot find the drug Cyclosporine (Sandimmune) in FDA dataset.
# Cannot find the drug Viagra in FDA dataset.
# Cannot find the drug Aspiri in FDA dataset.
# Cannot find the drug levo in FDA dataset.
# Cannot find the drug levo in FDA dataset.
# Cannot find the drug Ditropan XL in FDA dataset.
# Cannot find the drug Levoth in FDA dataset.
# Cannot find the drug Levoth in FDA dataset.
# Cannot find the drug Mult in FDA dataset.
# Cannot find the drug Corzide in FDA dataset.
# Cannot find the drug Campral in FDA dataset.
# Cannot find the drug *NF* Pregabalin in FDA dataset.
# Cannot find the drug dival in FDA dataset.
# Cannot find the drug Chloroprocaine 2% in FDA dataset.
# Cannot find the drug levocar in FDA dataset.
# Cannot find the drug Fentanyl Citrate in FDA dataset.
# Cannot find the drug Xylocaine in FDA dataset.
# Cannot find the drug Adderall in FDA dataset.
# Cannot find the drug *NF* Enfuvirtide in FDA dataset.
# Cannot find the drug AMICAR in FDA dataset.
# Cannot find the drug prednis in FDA dataset.
# Cannot find the drug Enfuvirtide in FDA dataset.
# Cannot find the drug *NF* Urea in FDA dataset.
# Cannot find the drug cilos in FDA dataset.
# Cannot find the drug sodi in FDA dataset.
# Cannot find the drug *NF* Ivermectin in FDA dataset.
# Cannot find the drug Buprenorphine HCl in FDA dataset.
# Cannot find the drug Lidocaine in FDA dataset.
# Cannot find the drug Sodium Citrate in FDA dataset.
# Cannot find the drug Lumigan *NF* in FDA dataset.
# Cannot find the drug Diprosone in FDA dataset.
# Cannot find the drug Fuzeon in FDA dataset.
# Cannot find the drug Carbamazepine Chewable Tabs in FDA dataset.
# Cannot find the drug albut in FDA dataset.
# Cannot find the drug TMC125 200mg/placebo po BID per Tibotec  in FDA dataset.
# Cannot find the drug insul in FDA dataset.
# Cannot find the drug NEO*IV*Epoetin Alfa in FDA dataset.
# Cannot find the drug NEO*SC*Epoetin Alfa in FDA dataset.
# Cannot find the drug Clobetasol Propionate 0.05% Gel in FDA dataset.
# Cannot find the drug PENTASA in FDA dataset.
# Cannot find the drug Chloral Hydrate in FDA dataset.
# Cannot find the drug Terconazole 0.4% Vag. Cream in FDA dataset.
# Cannot find the drug Meningococcal Vac A,C,Y,W-135 in FDA dataset.
# Cannot find the drug haemo in FDA dataset.
# Cannot find the drug Prilosec in FDA dataset.
# Cannot find the drug Triamcinolone 0.1% Cream in FDA dataset.
# Cannot find the drug Azelastine HCl in FDA dataset.
# Cannot find the drug Diprosone in FDA dataset.
# Cannot find the drug sulfa in FDA dataset.
# Cannot find the drug Flonase in FDA dataset.
# Cannot find the drug guaife in FDA dataset.
# Cannot find the drug Epinephri in FDA dataset.
# Cannot find the drug Amino Acids 3.5% in FDA dataset.
# Cannot find the drug Didanosine EC in FDA dataset.
# Cannot find the drug Aptivus in FDA dataset.
# Cannot find the drug Aptivus in FDA dataset.
# Cannot find the drug Arava in FDA dataset.
# Cannot find the drug Lidocaine 2%/Epinephrine in FDA dataset.
# Cannot find the drug Aminocaproic Acid 25% Oral Rinse in FDA dataset.
# Cannot find the drug Pneumococcal 7-Valent in FDA dataset.
# Cannot find the drug Belladonna & Opium in FDA dataset.
# Cannot find the drug Bupivacaine in FDA dataset.
# Cannot find the drug *NF* VYTONE CREAM in FDA dataset.
# Cannot find the drug CLARITIN in FDA dataset.
# Cannot find the drug Peridex in FDA dataset.
# Cannot find the drug aspir in FDA dataset.
# Cannot find the drug *NF* Cefotaxime in FDA dataset.
# Cannot find the drug Junel FE 1/20 (28) in FDA dataset.
# Cannot find the drug HYDROmorphone PCA in FDA dataset.
# Cannot find the drug Aranesp in FDA dataset.
# Cannot find the drug *NF* Lidocaine Patch 5% in FDA dataset.
# Cannot find the drug Ciprofloxacin Hcl in FDA dataset.
# Cannot find the drug Glucovance (2.5mg-500mg) in FDA dataset.
# Cannot find the drug Diovan/Hydrochlorthiazide in FDA dataset.
# Cannot find the drug Midrin in FDA dataset.
# Cannot find the drug PHENYLEPHRINE HCL in FDA dataset.
# Cannot find the drug NEO*PO*Propranolol in FDA dataset.
# Cannot find the drug PHENYLEPHRINE HCL in FDA dataset.
# Cannot find the drug LIDOCAINE 1% (W/Presv.) in FDA dataset.
# Cannot find the drug Cozaar in FDA dataset.
# Cannot find the drug Mebaral in FDA dataset.
# Cannot find the drug Heparin Flush (1000 units/ml) in FDA dataset.
# Cannot find the drug UNIP in FDA dataset.
# Cannot find the drug Peridex in FDA dataset.
# Cannot find the drug Lidocaine Viscous 2% in FDA dataset.
# Cannot find the drug Ethanol 70% Catheter Lock in FDA dataset.
# Cannot find the drug Lidocaine  in FDA dataset.
# Cannot find the drug Tamoxifen Citrate in FDA dataset.
# Cannot find the drug Ondansetron HCl in FDA dataset.
# Cannot find the drug *NF* Valacyclovir in FDA dataset.
# Cannot find the drug Stanozolol (Bulk) in FDA dataset.
# Cannot find the drug albuter in FDA dataset.
# Cannot find the drug Bupivacain in FDA dataset.
# Cannot find the drug clo in FDA dataset.
# Cannot find the drug clomi in FDA dataset.
# Cannot find the drug PARCOPA in FDA dataset.
# Cannot find the drug *NF* Fenofibrate in FDA dataset.
# Cannot find the drug *NF* Cefixime Suspension in FDA dataset.
# Cannot find the drug Tiagabine HCl in FDA dataset.
# Cannot find the drug maalox in FDA dataset.
# Cannot find the drug Doxil in FDA dataset.
# Cannot find the drug *NF* Amoxapine in FDA dataset.
# Cannot find the drug Procainamide HCl in FDA dataset.
# Cannot find the drug Neo-Synephrine in FDA dataset.
# Cannot find the drug Neo-Synephrine in FDA dataset.
# Cannot find the drug Desmopressi in FDA dataset.
# Cannot find the drug *NF* Cefotetan in FDA dataset.
# Cannot find the drug NS in FDA dataset.
# Cannot find the drug Soln in FDA dataset.
# Cannot find the drug Sodium Chloride 3% (Hypertonic) in FDA dataset.
# Cannot find the drug *NF* Phenytoin Sodium **Brand Name ONLY** in FDA dataset.
# Cannot find the drug Phenytoin Sodium **Brand Name ONLY** in FDA dataset.
# Cannot find the drug Nystatin-Triamcinolone Cream in FDA dataset.
# Cannot find the drug Dilantin in FDA dataset.
# Cannot find the drug Bupivacaine 0.1% in FDA dataset.
# Cannot find the drug Lidocaine 2% in FDA dataset.
# Cannot find the drug Albumin 5% (2.5gm) in FDA dataset.
# Cannot find the drug arti in FDA dataset.
# Cannot find the drug PROPOF in FDA dataset.
# Cannot find the drug estrogen/medroxyprogestrone in FDA dataset.
# Cannot find the drug sodiu in FDA dataset.
# Cannot find the drug Zymar in FDA dataset.
# Cannot find the drug Oxycodone SR (OxyconTIN) in FDA dataset.
# Cannot find the drug Vitamin E in FDA dataset.
# Cannot find the drug Sanctura in FDA dataset.
# Cannot find the drug Terbinafine 1% Spray in FDA dataset.
# Cannot find the drug Methyl Salicylate-Menthol Ointment in FDA dataset.
# Cannot find the drug Benefiber in FDA dataset.
# Cannot find the drug MEGACE in FDA dataset.
# Cannot find the drug Lotensin in FDA dataset.
# Cannot find the drug clobetisol propionate ointment  in FDA dataset.
# Cannot find the drug Sulfameth/Trimethoprim in FDA dataset.
# Cannot find the drug Bicitra in FDA dataset.
# Cannot find the drug LANSOPR in FDA dataset.
# Cannot find the drug Revatio (sildenafil citrate) in FDA dataset.
# Cannot find the drug Revatio in FDA dataset.
# Cannot find the drug Revatio (sildenafil) in FDA dataset.
# Cannot find the drug Tracleer in FDA dataset.
# Cannot find the drug Librax in FDA dataset.
# Cannot find the drug Parecoxib/Placebo in FDA dataset.
# Cannot find the drug Parecoxib/Placebo Study Med in FDA dataset.
# Cannot find the drug Valdecoxib/placebo in FDA dataset.
# Cannot find the drug viread in FDA dataset.
# Cannot find the drug Nicotine Lozenge in FDA dataset.
# Cannot find the drug Gentamicin ophth oint 0.3% in FDA dataset.
# Cannot find the drug Tol in FDA dataset.
# Cannot find the drug Abilify in FDA dataset.
# Cannot find the drug Hyoscy in FDA dataset.
# Cannot find the drug *NF* Tobramycin Soln in FDA dataset.
# Cannot find the drug Concerta 18mg in FDA dataset.
# Cannot find the drug Concerta in FDA dataset.
# Cannot find the drug methylph in FDA dataset.
# Cannot find the drug Concerta  in FDA dataset.
# Cannot find the drug CONCERTA in FDA dataset.
# Cannot find the drug ERYTHROMYCIN 0.5% OPHTH OINT in FDA dataset.
# Cannot find the drug VITAMIN K*NEO in FDA dataset.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-7cae06ed5cd0> in <module>
#       1 ## Search unii codes for drugs in MIMIC3
# ----> 2 pres_drugs['UNII'] = pres_drugs['DRUG'].apply(get_unii)
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-15-1c968928f1b1> in get_unii(drug_name)
#       2 def get_unii(drug_name):
#       3     fda_api = 'https://api.fda.gov/drug/label.json?search=openfda.generic_name:%s&limit=1' % drug_name
# ----> 4     r = requests.get(fda_api)
#       5     try:
#       6         return set(r.json()['results'][0]['openfda']['unii'])
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/urllib3/connection.py in connect(self)
#     299     def connect(self):
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#     303
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/urllib3/connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:

# %%
#0.9% Sodium Chloride
bank_drugs.head()
# Out:
#   drugbank_id                 name
# 0     DB00001            Lepirudin
# 1     DB00002            Cetuximab
# 2     DB00003         Dornase alfa
# 3     DB00004  Denileukin diftitox
# 4     DB00005           Etanercept

# %% [markdown]
# ### DRUG x name, transform all letters of drug names to lower case

# %%
# pres_drugs['DRUG_lower'] = pres_drugs['DRUG'].str.lower()
# bank_drugs['DRUG_lower'] = bank_drugs['name'].str.lower()
sider_drugs['DRUG_lower'] = sider_drugs['drugbank_name'].str.lower()

# %%
map_BP_drugs = aa.left_join(pres_drugs,bank_drugs,'DRUG_lower')
map_BP_drugs.head()
# Out:
#              DRUG          NDC      DRUG_lower drugbank_id        name
# 0      Tacrolimus  00469061711      tacrolimus     DB00864  Tacrolimus
# 1        Warfarin  00056017275        warfarin     DB00682    Warfarin
# 2  Heparin Sodium  00338055002  heparin sodium         NaN         NaN
# 3             D5W            0             d5w         NaN         NaN
# 4      Furosemide  00054829725      furosemide     DB00695  Furosemide

# %%
a=map_BP_drugs[map_BP_drugs['drugbank_id'].notna()].head()
# Out:
#                DRUG          NDC       DRUG_lower drugbank_id name
# 2    Heparin Sodium  00338055002   heparin sodium         NaN  NaN
# 3               D5W            0              d5w         NaN  NaN
# 10      Neutra-Phos  17314931102      neutra-phos         NaN  NaN
# 11   Heparin Sodium  00074779362   heparin sodium         NaN  NaN
# 13  Docusate Sodium  51079001920  docusate sodium         NaN  NaN

# %%
51079001920
# len(side_effect_df['drugbank_name'].unique())
# len(pres_drugs['DRUG'].unique())
# b=sider_drugs[sider_drugs['drugbank_name']=='Mupirocin']
"2999F27MAD",
          "O18YUO0I83",
          "R60L0SM5BC"
        NMH84OZK2B

# %%
# import json
import requests

response = requests.get('https://api.fda.gov/drug/label.json?search=openfda.generic_name:Ondansetron&limit=1')
# json_data = json.loads(response.text)

# %%
response.json()['results'][0]['openfda']['unii']
# Out:
# ['NMH84OZK2B']

# %%
# response2 = requests.get('https://api.fda.gov/drug/label.json?search=openfda.product_ndc:"0173-0569"&limit=1')
set(response2.json()['results'][0]['openfda']['unii'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-de89ba33469b> in <module>
#       1 # response2 = requests.get('https://api.fda.gov/drug/label.json?search=openfda.product_ndc:"0173-0569"&limit=1')
# ----> 2 set(response2.json()['results'][0]['openfda']['unii']).sort()
#
# AttributeError: 'set' object has no attribute 'sort'

# %% [markdown]
# ## draft

# %%
drugbank_list[drugbank_list['drugbank_id']=='DB00904'].head()
# Out:
#     drugbank_id         name            type    groups atc_codes  \
# 893     DB00904  Ondansetron  small molecule  approved   A04AA01
#
#                categories                              inchikey  \
# 893  Antipsychotic Agents  InChIKey=FELGMEQIXOGIFQ-UHFFFAOYSA-N
#
#                                                  inchi  \
# 893  InChI=1S/C18H19N3O/c1-12-19-9-10-21(12)11-13-7...
#
#                                            description
# 893  A competitive serotonin type 3 receptor antago...

# %%
drugbank_list = list(zip(*drugbank_list))

# %%
drugbank_map = dict(zip(drugbank_list[0],drugbank_list[1]))
drugbank_map['Dulaglutide']
# Out:
# 'DB09045'

# %%
del drugbank_list
pres_df.head()
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTDATE  \
# 0  2214776           6   107064         NaN  2175-06-11 00:00:00
# 1  2214775           6   107064         NaN  2175-06-11 00:00:00
# 2  2215524           6   107064         NaN  2175-06-11 00:00:00
# 4  2214773           6   107064         NaN  2175-06-11 00:00:00
# 5  2214774           6   107064         NaN  2175-06-11 00:00:00
#
#                ENDDATE DRUG_TYPE            DRUG DRUG_NAME_POE  \
# 0  2175-06-12 00:00:00      MAIN      Tacrolimus    Tacrolimus
# 1  2175-06-12 00:00:00      MAIN        Warfarin      Warfarin
# 2  2175-06-12 00:00:00      MAIN  Heparin Sodium           NaN
# 4  2175-06-12 00:00:00      MAIN      Furosemide    Furosemide
# 5  2175-06-15 00:00:00      MAIN        Warfarin      Warfarin
#
#   DRUG_NAME_GENERIC FORMULARY_DRUG_CD     GSN          NDC  \
# 0        Tacrolimus             TACR1  021796  00469061711
# 1          Warfarin             WARF5  006562  00056017275
# 2               NaN        HEPAPREMIX  006522  00338055002
# 4        Furosemide            FURO20  008208  00054829725
# 5          Warfarin             WARF0  014198  00056016975
#
#             PROD_STRENGTH DOSE_VAL_RX DOSE_UNIT_RX FORM_VAL_DISP  \
# 0             1mg Capsule           2           mg             2
# 1              5mg Tablet           5           mg             1
# 2  25,000 unit Premix Bag      25,000         UNIT             1
# 4             20mg Tablet          20           mg             1
# 5  Check with MD for Dose           1         dose             1
#
#   FORM_UNIT_DISP ROUTE  NDC_length
# 0            CAP    PO          11
# 1            TAB    PO          11
# 2            BAG    IV          11
# 4            TAB    PO          11
# 5           dose    PO          11

# %%
test = pd.DataFrame({'DRUG':pres_df['DRUG'].unique()})

# %%
def drug2id(drug): 
    try:
        return drugbank_map[drug]
    except KeyError as error:
        return np.nan

# %%
test['drugbank_id'] = pres_df['DRUG'].apply(lambda x: drug2id(x.title()))

# %%
test.head()
# Out:
#              DRUG
# 0      Tacrolimus
# 1        Warfarin
# 2  Heparin Sodium
# 3             D5W
# 4      Furosemide

# %%
test[test['drugbank_id'].isna()].count()
# Out:
# DRUG           2780
# drugbank_iD       0
# dtype: int64

# %%
side_effect_df[side_effect_df['drugbank_id']=='DB00904'].head()
# Out:
#        drugbank_id drugbank_name umls_cui_from_meddra         side_effect_name
# 103667     DB00904   Ondansetron             C0000737           Abdominal pain
# 103668     DB00904   Ondansetron             C0152198   Accommodation disorder
# 103669     DB00904   Ondansetron             C0948089  Acute coronary syndrome
# 103670     DB00904   Ondansetron             C0085631                Agitation
# 103671     DB00904   Ondansetron             C0392156                Akathisia

# %%
bank_drug_test = side_effect_df[['drugbank_id','drugbank_name']].drop_duplicates()
len(bank_drug_test)
# Out:
# 1223

# %%
aa.left_join(bank_drug_test,test,'drugbank_id')
# Out:
#      drugbank_id                                      drugbank_name  \
# 0        DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 1        DB07886  (11alpha,14beta)-11,17,21-trihydroxypregn-4-en...
# 2        DB07702  (16ALPHA,17ALPHA)-ESTRA-1,3,5(10)-TRIENE-3,16,...
# 3        DB07465  (1S,3S,5S)-2-{(2S)-2-amino-2-[(1R,3S,5R,7S)-3-...
# 4        DB08567  (1S,4S)-4-(3,4-dichlorophenyl)-N-methyl-1,2,3,...
# 5        DB07129         (2R)-1-(2,6-dimethylphenoxy)propan-2-amine
# 6        DB08298    (2S)-2-(6-methoxynaphthalen-2-yl)propanoic acid
# 7        DB02932  (2r)-N-[4-Cyano-3-(Trifluoromethyl)Phenyl]-3-[...
# 8        DB02648  (3-Carboxy-2-(R)-Hydroxy-Propyl)-Trimethyl-Amm...
# 9        DB08472  (3R)-N-methyl-3-phenyl-3-[4-(trifluoromethyl)p...
# 10       DB08544  (3S)-N-methyl-3-phenyl-3-[4-(trifluoromethyl)p...
# 11       DB08607  (5R)-5-(4-{[(2R)-6-HYDROXY-2,5,7,8-TETRAMETHYL...
# 12       DB02692           (6r,1'r,2's)-5,6,7,8 Tetrahydrobiopterin
# 13       DB03151            (Mu-4-Sulfido)-Tetra-Nuclear Copper Ion
# 14       DB02032  1-(3-Mercapto-2-Methyl-Propionyl)-Pyrrolidine-...
# 15       DB03322    1-(Isopropylamino)-3-(1-Naphthyloxy)-2-Propanol
# 16       DB07701  1-BENZYL-4-[(5,6-DIMETHOXY-1-INDANON-2-YL)METH...
# 17       DB07705  1-[(2S)-2-[(4-CHLOROBENZYL)OXY]-2-(2,4-DICHLOR...
# 18       DB03125  2,4-Diamino-5-(3,4,5-Trimethoxy-Benzyl)-Pyrimi...
# 19       DB06987  2-(4-(2-HYDROXY-3-(ISOPROPYLAMINO)PROPOXY)PHEN...
# 20       DB04084                   2-Deoxy-2-Fluoro-Alpha-D-Mannose
# 21       DB04483                    2-Deoxy-2-Fluoro-Beta-D-Mannose
# 22       DB04282                            2-Deoxy-2fluoro-Glucose
# 23       DB02228            2-Fluoro-2-Deoxy-Beta-D-Galactopyranose
# 24       DB04441                                  2-Fluoroadenosine
# 25       DB08046  2-chloro-5-[(1S)-1-hydroxy-3-oxo-2H-isoindol-1...
# 26       DB08167           3,7-BIS(DIMETHYLAMINO)PHENOTHIAZIN-5-IUM
# 27       DB08700  3-[(1R)-1-(2,6-dichloro-3-fluorophenyl)ethoxy]...
# 28       DB08183  3-{(3R,4R)-4-methyl-3-[methyl(7H-pyrrolo[2,3-d...
# 29       DB01671                     4-(Hydroxymercury)Benzoic Acid
# ...          ...                                                ...
# 2699     DB00582                                       Voriconazole
# 2700     DB02546                                         Vorinostat
# 2701     DB05389                                               WF10
# 2702     DB00549                                        Zafirlukast
# 2703     DB00943                                        Zalcitabine
# 2704     DB00962                                           Zaleplon
# 2705     DB00558                                          Zanamivir
# 2706     DB00495                                         Zidovudine
# 2707     DB00495                                         Zidovudine
# 2708     DB00744                                           Zileuton
# 2709     DB01593                                               Zinc
# 2710     DB02165                                  Zinc Trihydroxide
# 2711     DB00246                                        Ziprasidone
# 2712     DB00399                                        Zoledronate
# 2713     DB00315                                       Zolmitriptan
# 2714     DB00425                                           Zolpidem
# 2715     DB00909                                         Zonisamide
# 2716     DB01198                                          Zopiclone
# 2717     DB01624                                     Zuclopenthixol
# 2718     DB01794                bis(molybdopterin)tungsten cofactor
# 2719     DB05381                          histamine dihydrochloride
# 2720     DB05347                            iontophoretic acyclovir
# 2721     DB05291                                    lidocaine patch
# 2722     DB05428                               motexafin gadolinium
# 2723     DB05296                                 motexafin lutetium
# 2724     DB05302                                   naltrexone depot
# 2725     DB08439                                          parecoxib
# 2726     DB05383                                     pimagedine HCl
# 2727     DB07424  tripotassium (1R)-4-biphenyl-4-yl-1-phosphonat...
# 2728     DB05738                         vapitadine dihydrochloride
#
#             DRUG
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# ...          ...
# 2699         NaN
# 2700         NaN
# 2701         NaN
# 2702         NaN
# 2703         NaN
# 2704         NaN
# 2705         NaN
# 2706  Zofran ODT
# 2707      Humira
# 2708         NaN
# 2709         NaN
# 2710         NaN
# 2711         NaN
# 2712         NaN
# 2713         NaN
# 2714         NaN
# 2715         NaN
# 2716         NaN
# 2717         NaN
# 2718         NaN
# 2719         NaN
# 2720         NaN
# 2721         NaN
# 2722         NaN
# 2723         NaN
# 2724         NaN
# 2725         NaN
# 2726         NaN
# 2727         NaN
# 2728         NaN
#
# [2729 rows x 3 columns]

# %%
pres_df[pres_df['DRUG']=='Zofran ODT']
# Out:
#          SUBJECT_ID            STARTDATE              ENDDATE        DRUG  \
# 1678741       23479  2151-12-03 00:00:00  2151-12-03 00:00:00  Zofran ODT
#
#                  NDC ROUTE
# 1678741  00173056900  ORAL

# %%
drug_indication_df[drug_indication_df['drugbank_id']=='DB00904'].head()
# Out:
#      drugbank_id drugbank_name  pubchem_id stitch_id_flat umls_cui_from_label  \
# 8466     DB00904   Ondansetron        4595   CID100004595            C0006826
# 8467     DB00904   Ondansetron        4595   CID100004595            C0027497
# 8468     DB00904   Ondansetron        4595   CID100004595            C0042963
# 8469     DB00904   Ondansetron        4595   CID100004595            C0520904
#
#               method          concept_name meddra_type umls_cui_from_meddra  \
# 8466  NLP_indication   Malignant Neoplasms          PT             C0006826
# 8467  NLP_indication                Nausea          PT             C0027497
# 8468  NLP_indication              Vomiting          PT             C0042963
# 8469  NLP_indication  Postoperative Nausea          PT             C1868752
#
#              meddra_name
# 8466  Neoplasm malignant
# 8467              Nausea
# 8468            Vomiting
# 8469   Procedural nausea

# %%
test
# Out:
#                                   DRUG drugbank_id
# 0                           Tacrolimus     DB00864
# 1                             Warfarin     DB00682
# 2                       Heparin Sodium         NaN
# 3                                  D5W         NaN
# 4                           Furosemide     DB00695
# 5                Mycophenolate Mofetil     DB00682
# 6                          Neutra-Phos         NaN
# 7                        Nitroglycerin         NaN
# 8                      Docusate Sodium         NaN
# 9                              Insulin     DB00682
# 10                    Atropine Sulfate         NaN
# 11                   Zolpidem Tartrate     DB00864
# 12                       Midazolam HCl     DB00864
# 13                    Nitroglycerin SL         NaN
# 14                           Lorazepam     DB00864
# 15                   Magnesium Sulfate     DB00864
# 16                  Potassium Chloride         NaN
# 17                           Ketorolac         NaN
# 18                          Sucralfate     DB00682
# 19                      Vancomycin HCl         NaN
# 20                Iso-Osmotic Dextrose     DB00864
# 21                       Acetaminophen     DB00864
# 22             Oxycodone-Acetaminophen         NaN
# 23                      Metoclopramide         NaN
# 24                    Morphine Sulfate         NaN
# 25                          Meperidine     DB00727
# 26                Nitroprusside Sodium         NaN
# 27                                  SW         NaN
# 28                   Calcium Gluconate         NaN
# 29                 Dolasetron Mesylate         NaN
# ...                                ...         ...
# 4495                          Guaifene     DB00512
# 4496                         sodium ch     DB01413
# 4497                 Lidocaine Topical         NaN
# 4498                           bisopro         NaN
# 4499                 Isordil Titradose         NaN
# 4500                            bisopr         NaN
# 4501                             bisop         NaN
# 4502               Haloperidol Lactate         NaN
# 4503  Lactobacillus Acidophilus-Pectin         NaN
# 4504        fluocinolone acetonide oil         NaN
# 4505                       olopatadine         NaN
# 4506                        bisoprolol         NaN
# 4507                          Dexilant         NaN
# 4508        dexlansoprazole (Dexilant)         NaN
# 4509                               anu         NaN
# 4510                               Ola         NaN
# 4511                             Xyzal     DB00868
# 4512                          Pacerone     DB00316
# 4513                       Tacrolimus      DB00829
# 4514                       naratriptan         NaN
# 4515                     Betamethasone     DB00581
# 4516   vancoMYCIN for nasal inhalation     DB00904
# 4517         vancoMYCIN for inhalation         NaN
# 4518            Erythromycin opthalmic     DB00413
# 4519      *NF* Butorphanol Tart. Nasal         NaN
# 4520                              Vera     DB00706
# 4521                        Advair HFA         NaN
# 4522               Paroxetine Mesylate     DB01413
# 4523                       Ipratropium     DB00207
# 4524              rasagiline (Azilect)         NaN
#
# [4525 rows x 2 columns]

# %%
drugbank_map['Zofran ODT']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-155-5cf081d77cfc> in <module>
# ----> 1 drugbank_map['Zofran ODT']
#
# KeyError: 'Zofran ODT'

# %%
test[test['DRUG']=='Zofran ODT']
# Out:
#             DRUG drugbank_id
# 3245  Zofran ODT     DB00495

# %%
bank_drug_test[bank_drug_test['drugbank_id']=='DB00495']
# Out:
#        drugbank_id drugbank_name
# 150563     DB00495    Zidovudine

# %%
drug2id('Zofran ODT')
# Out:
# nan

# %%
'Zofran ODT'.title()
# Out:
# 'Zofran Odt'
